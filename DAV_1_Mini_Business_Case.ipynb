# %% [markdown]
# <a href="https://colab.research.google.com/github/adityajain2407/DAV-1-apr23/blob/main/DAV_1_Mini_Business_Case.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Purpose:
#
# *   Question-Answer format -> to first let learners solve and then resolve queries if any
# *   To discuss various appraoches wherever possible
# *   Introduce the usecase of the concepts learnt in a systematic flow
# *   To discuss business insights
# *   Discussing scalability ideas and how to validate logic using a subset

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #load the dataset

# %%
# !gdown 1s2TkjSpzNc4SyxqRrQleZyDIHlc7bxnd
# !gdown 1Ws-_s1fHZ9nHfGLVUQurbHDvStePlEJm
movies = pd.read_csv('movies.csv')
directors = pd.read_csv('directors.csv')
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1s2TkjSpzNc4SyxqRrQleZyDIHlc7bxnd
# To: /content/movies.csv
# 100% 112k/112k [00:00<00:00, 14.5MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1Ws-_s1fHZ9nHfGLVUQurbHDvStePlEJm
# To: /content/directors.csv
# 100% 65.4k/65.4k [00:00<00:00, 92.3MB/s]

# %%
movies.head()
# Out:
#    Unnamed: 0     id     budget  popularity     revenue  \
# 0           0  43597  237000000         150  2787965087
# 1           1  43598  300000000         139   961000000
# 2           2  43599  245000000         107   880674609
# 3           3  43600  250000000         112  1084939099
# 4           5  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day
# 0         4762  2009   Dec  Thursday
# 1         4763  2007   May  Saturday
# 2         4764  2015   Oct    Monday
# 3         4765  2012   Jul    Monday
# ...

# %%
#remove the unnecessary column
movies.drop(columns = ["Unnamed: 0"], inplace = True)

# %%
directors.head()
# Out:
#    Unnamed: 0      director_name    id gender
# 0           0      James Cameron  4762   Male
# 1           1     Gore Verbinski  4763   Male
# 2           2         Sam Mendes  4764   Male
# 3           3  Christopher Nolan  4765   Male
# 4           4     Andrew Stanton  4766   Male

# %%
#remove the unnecessary column
directors.drop(columns = ["Unnamed: 0"], inplace = True)

# %%
directors.head()
# Out:
#        director_name    id gender
# 0      James Cameron  4762   Male
# 1     Gore Verbinski  4763   Male
# 2         Sam Mendes  4764   Male
# 3  Christopher Nolan  4765   Male
# 4     Andrew Stanton  4766   Male

# %% [markdown]
# # q1- How many years of data is given to you in the movies dataset?
#
# column aggregation
#
# *   List item
# *   List item

# %%
no_of_years = movies["year"].max() - movies["year"].min()
print(no_of_years)
# Out:
# 40

# %% [markdown]
# #q2 - Display the ReleaseDate in the Day-Month-Year format --> row level operations
#
#
#
# *   List item
# *   List item

# %%
releaseDate = movies["day"] + "-" + movies["month"] + "-" + movies["year"]
print(releaseDate[:5])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/ops/array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     164     try:
# --> 165         result = func(left, right)
#     166     except TypeError:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/computation/expressions.py in evaluate(op, a, b, use_numexpr)
#     240             # error: "None" not callable
# --> 241             return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     242     return _evaluate_standard(op, op_str, a, b)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/computation/expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     128     if result is None:
# --> 129         result = _evaluate_standard(op, op_str, a, b)
#     130
#
# ...

# %%
#confirm error by checking the datatypes of the columns
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            1465 non-null   int64
#  1   budget        1465 non-null   int64
#  2   popularity    1465 non-null   int64
#  3   revenue       1465 non-null   int64
#  4   title         1465 non-null   object
#  5   vote_average  1465 non-null   float64
#  6   vote_count    1465 non-null   int64
#  7   director_id   1465 non-null   int64
#  8   year          1465 non-null   int64
#  9   month         1465 non-null   object
#  10  day           1465 non-null   object
# dtypes: float64(1), int64(7), object(3)
# memory usage: 126.0+ KB

# %%
#obs: as year is in int format, need to typecast before concatenation
releaseDate = movies["day"] + "-" + movies["month"] + "-" + movies["year"].astype("str")
print(releaseDate[:5])
# Out:
# 0    Thursday-Dec-2009
# 1    Saturday-May-2007
# 2      Monday-Oct-2015
# 3      Monday-Jul-2012
# 4     Tuesday-May-2007
# dtype: object

# %% [markdown]
# #Q4- What is the % of men directors in the given data

# %%
directors["gender"].value_counts()
# Out:
# Male      1574
# Female     150
# Name: gender, dtype: int64

# %%
directors["gender"].value_counts(normalize = True)
# Out:
# Male      0.912993
# Female    0.087007
# Name: gender, dtype: float64

# %%
directors["gender"].value_counts(normalize = True)*100
#91% of the directors in the dataset are Male
# Out:
# Male      91.299304
# Female     8.700696
# Name: gender, dtype: float64

# %% [markdown]
# #Weekday vs Weekend release analysis

# %%
movies["day"].value_counts()
# Out:
# Friday       654
# Thursday     277
# Wednesday    276
# Tuesday       98
# Monday        67
# Saturday      47
# Sunday        46
# Name: day, dtype: int64

# %%
movies["day"].value_counts(normalize=True)*100
# Out:
# Friday       44.641638
# Thursday     18.907850
# Wednesday    18.839590
# Tuesday       6.689420
# Monday        4.573379
# Saturday      3.208191
# Sunday        3.139932
# Name: day, dtype: float64

# %% [markdown]
# # Q2- How many different movies have been directed in the year 2010?- single masking

# %%
movies2010 = movies[ movies["year"] == 2010 ]

# %%
len(movies2010) #as every row is unique movie
# Out:
# 63

# %%
movies2010["id"].nunique()
# Out:
# 63

# %% [markdown]
# # Q1- How many different directors have directed a movie since 2010

# %%
sample = movies[movies["year"] >= 2010]
sample["director_id"].nunique()
# Out:
# 163

# %%
ids = sample["director_id"].unique()
print(ids[:5])
names = directors[directors["id"].isin(ids)]["director_name"]
# Out:
# [4764 4765 4771 4763 4775]

# %%
print(names)
names.count() #validate
# Out:
# 1            Gore Verbinski
# 2                Sam Mendes
# 3         Christopher Nolan
# 5                 Sam Raimi
# 9               Zack Snyder
#                ...
# 1132          Brad Anderson
# 1189         Michael Polish
# 1208          Paul Schrader
# 1294    Darren Lynn Bousman
# 1442      Nicole Holofcener
# Name: director_name, Length: 163, dtype: object
# 163

# %% [markdown]
# #Q4- Display the name of the director who directed Spider-Man 3 movie.

# %%
#without merging
df = movies[movies["title"] == "Spider-Man 3"]
df
# Out:
#       id     budget  popularity    revenue         title  vote_average  \
# 4  43602  258000000         115  890871626  Spider-Man 3           5.9
#
#    vote_count  director_id  year month      day
# 4        3576         4767  2007   May  Tuesday

# %%
director_id = df["director_id"]
director_id
# Out:
# 4    4767
# Name: director_id, dtype: int64

# %%
director_id.reset_index(drop = True, inplace = True)
director_id
# Out:
# 0    4767
# Name: director_id, dtype: int64

# %%
id = director_id[0]

# %%
name = directors.loc[directors["id"] == id, "director_name" ]
print(name)
#google search and confirm as well
# Out:
# 5    Sam Raimi
# Name: director_name, dtype: object

# %%
#Appraoach2: better appraoch is to merge and then filter row
data = movies.merge(directors, how='inner', left_on='director_id',right_on='id')
data.drop(['director_id','id_y'],axis=1,inplace=True)

# %%
data.head()
# Out:
#     id_x     budget  popularity     revenue                       title  \
# 0  43597  237000000         150  2787965087                      Avatar
# 1  43622  200000000         100  1845034188                     Titanic
# 2  43876  100000000         101   520000000  Terminator 2: Judgment Day
# 3  43879  115000000          38   378882411                   True Lies
# 4  44184   70000000          24    90000098                   The Abyss
#
#    vote_average  vote_count  year month        day  director_name gender
# 0           7.2       11800  2009   Dec   Thursday  James Cameron   Male
# 1           7.5        7562  1997   Nov    Tuesday  James Cameron   Male
# 2           7.7        4185  1991   Jul     Monday  James Cameron   Male
# 3           6.8        1116  1994   Jul   Thursday  James Cameron   Male
# 4           7.1         808  1989   Aug  Wednesday  James Cameron   Male

# %%
name = data[data["title"] == "Spider-Man 3"]["director_name"]
print(name)
# Out:
# 29    Sam Raimi
# Name: director_name, dtype: object

# %% [markdown]
# #q3 - How many different movies have been directed by James Cameron between 2005 to 2010? - multi condition masking#

# %%
movies.head()
# Out:
#       id     budget  popularity     revenue  \
# 0  43597  237000000         150  2787965087
# 1  43598  300000000         139   961000000
# 2  43599  245000000         107   880674609
# 3  43600  250000000         112  1084939099
# 4  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day
# 0         4762  2009   Dec  Thursday
# 1         4763  2007   May  Saturday
# 2         4764  2015   Oct    Monday
# 3         4765  2012   Jul    Monday
# 4         4767  2007   May   Tuesday

# %%
james_id = directors.loc[ directors['director_name'] == "Gore Verbinski"]

# %%
james_id
# Out:
#     director_name    id gender
# 1  Gore Verbinski  4763   Male

# %%
james_id = directors.loc[ directors['director_name'] == "Gore Verbinski"].reset_index(drop = True)

# %%
james_id = directors.loc[ directors['director_name'] == "Gore Verbinski"].reset_index(drop = True)["id"][0]

# %%
james_id
# Out:
# 4763

# %%
james_movies = movies.loc[ (movies["director_id"] == james_id) & (movies["year"] >= 2000) & (movies["year"] <= 2015)]
james_movies
# Out:
#          id     budget  popularity     revenue  \
# 1     43598  300000000         139   961000000
# 8     43609  200000000         145  1065659812
# 9     43610  255000000          49    89289910
# 107   43775  135000000          29   245724603
# 119   43796  140000000         271   655011224
# 633   44780   57000000          21   147845033
# 1040  45801   20000000          14    12482775
#
#                                                   title  vote_average  \
# 1              Pirates of the Caribbean: At World's End           6.9
# 8            Pirates of the Caribbean: Dead Man's Chest           7.0
# 9                                       The Lone Ranger           5.9
# 107                                               Rango           6.6
# 119   Pirates of the Caribbean: The Curse of the Bla...           7.5
# 633                                         The Mexican           5.8
# 1040                                    The Weather Man           6.0
#
# ...

# %%
def solve(director_name, start_year, end_year):
  director_id = directors.loc[ directors['director_name'] == director_name].reset_index(drop = True)["id"][0]

  director_movies = movies.loc[(movies["director_id"] == director_id)]

  df = director_movies.loc[ (director_movies["year"] >= start_year) & (director_movies["year"] <= end_year) ]

  return df

# %%
solve("James Cameron", 2000, 2015)
# Out:
#       id     budget  popularity     revenue   title  vote_average  vote_count  \
# 0  43597  237000000         150  2787965087  Avatar           7.2       11800
#
#    director_id  year month       day
# 0         4762  2009   Dec  Thursday

# %%
solve("Gore Verbinski", 2000, 2015)
# Out:
#          id     budget  popularity     revenue  \
# 1     43598  300000000         139   961000000
# 8     43609  200000000         145  1065659812
# 9     43610  255000000          49    89289910
# 107   43775  135000000          29   245724603
# 119   43796  140000000         271   655011224
# 633   44780   57000000          21   147845033
# 1040  45801   20000000          14    12482775
#
#                                                   title  vote_average  \
# 1              Pirates of the Caribbean: At World's End           6.9
# 8            Pirates of the Caribbean: Dead Man's Chest           7.0
# 9                                       The Lone Ranger           5.9
# 107                                               Rango           6.6
# 119   Pirates of the Caribbean: The Curse of the Bla...           7.5
# 633                                         The Mexican           5.8
# 1040                                    The Weather Man           6.0
#
# ...

# %%
solve("Aditya Jain", 2000, 2015)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/range.py in get_loc(self, key, method, tolerance)
#     390                 try:
# --> 391                     return self._range.index(new_key)
#     392                 except ValueError as err:
#
# ValueError: 0 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-33-04db7f0251b6> in <cell line: 1>()
# ----> 1 solve("Aditya Jain", 2000, 2015)
#
# <ipython-input-30-1c59d2036de6> in solve(director_name, start_year, end_year)
#       1 def solve(director_name, start_year, end_year):
# ----> 2   director_id = directors.loc[ directors['director_name'] == director_name].reset_index(drop = True)["id"][0]
#       3
# ...

# %%
#From industry's perspective, we try to make it robust to such conditions

# %%
def solve(director_name, start_year, end_year):


  df = directors[directors["director_name"] == director_name]

  if len(df) != 0:


    director_id = directors.loc[ directors['director_name'] == director_name].reset_index(drop = True)["id"][0]

    director_movies = movies.loc[(movies["director_id"] == director_id)]

    df = director_movies.loc[ (director_movies["year"] >= start_year) & (director_movies["year"] <= end_year) ]

    return df
  else:
    return "No movies directed!"

# %%
solve("Aditya Jain", 2000, 2015)
# Out:
# 'No movies directed!'

# %%
#the better industry standard is to write it using try batch block- will be covered in Advanced Python lectures.

# %% [markdown]
# ##Q5 - Among the top 10 most popular movies, which is the movie with the 2nd highest vote_avg?

# %%
top_popular_movies = movies.sort_values("popularity", ascending = False)
top_10_popular = top_popular_movies.head(10)
top_10_popular
# Out:
#         id     budget  popularity     revenue  \
# 58   43692  165000000         724   675120017
# 78   43724  150000000         434   378858340
# 119  43796  140000000         271   655011224
# 120  43797  125000000         206   752100229
# 45   43662  185000000         187  1004558444
# 162  43867  108000000         167   630161890
# 59   43693  160000000         167   825532764
# 5    43606  250000000         155   873260194
# 0    43597  237000000         150  2787965087
# 383  44259   63000000         146   100853753
#
#                                                  title  vote_average  \
# 58                                        Interstellar           8.1
# 78                                  Mad Max: Fury Road           7.2
# 119  Pirates of the Caribbean: The Curse of the Bla...           7.5
# 120              The Hunger Games: Mockingjay - Part 1           6.6
# 45                                     The Dark Knight           8.2
# ...

# %%
top_voted = top_10_popular.sort_values("vote_average", ascending = False)
top_voted
# Out:
#         id     budget  popularity     revenue  \
# 383  44259   63000000         146   100853753
# 45   43662  185000000         187  1004558444
# 58   43692  165000000         724   675120017
# 59   43693  160000000         167   825532764
# 162  43867  108000000         167   630161890
# 119  43796  140000000         271   655011224
# 78   43724  150000000         434   378858340
# 0    43597  237000000         150  2787965087
# 120  43797  125000000         206   752100229
# 5    43606  250000000         155   873260194
#
#                                                  title  vote_average  \
# 383                                         Fight Club           8.3
# 45                                     The Dark Knight           8.2
# 58                                        Interstellar           8.1
# 59                                           Inception           8.1
# 162                                        The Martian           7.6
# ...

# %%
ans = top_voted.iloc[[1]]
ans
# Out:
#        id     budget  popularity     revenue            title  vote_average  \
# 45  43662  185000000         187  1004558444  The Dark Knight           8.2
#
#     vote_count  director_id  year month        day
# 45       12002         4765  2008   Jul  Wednesday

# %%
top_popular_movies = movies.sort_values(["popularity", "vote_average"], ascending = [False, False])
top_popular_movies
# Out:
#          id     budget  popularity     revenue  \
# 58    43692  165000000         724   675120017
# 78    43724  150000000         434   378858340
# 119   43796  140000000         271   655011224
# 120   43797  125000000         206   752100229
# 45    43662  185000000         187  1004558444
# ...     ...        ...         ...         ...
# 1448  48233          0           0           0
# 1214  46452   12000000           0    12902790
# 1180  46303   14000000           0     2474000
# 1438  48145     500000           0           0
# 1437  48135          0           0           0
#
#                                                   title  vote_average  \
# 58                                         Interstellar           8.1
# 78                                   Mad Max: Fury Road           7.2
# 119   Pirates of the Caribbean: The Curse of the Bla...           7.5
# 120               The Hunger Games: Mockingjay - Part 1           6.6
# ...

# %% [markdown]
# ##Quiz: is the below code doing the same? - After their response, discuss in detail step by step how is it different

# %%
top_popular_movies = movies.sort_values(["popularity", "vote_average"], ascending = [False, False]).head(10).iloc[[1]]
top_popular_movies
# Out:
#        id     budget  popularity    revenue               title  vote_average  \
# 78  43724  150000000         434  378858340  Mad Max: Fury Road           7.2
#
#     vote_count  director_id  year month        day
# 78        9427         4845  2015   May  Wednesday

# %% [markdown]
# step-by-step breakdown

# %%
top_popular_movies = movies.sort_values(["popularity", "vote_average"], ascending = [False, False])
top_popular_movies
# Out:
#          id     budget  popularity     revenue  \
# 58    43692  165000000         724   675120017
# 78    43724  150000000         434   378858340
# 119   43796  140000000         271   655011224
# 120   43797  125000000         206   752100229
# 45    43662  185000000         187  1004558444
# ...     ...        ...         ...         ...
# 1448  48233          0           0           0
# 1214  46452   12000000           0    12902790
# 1180  46303   14000000           0     2474000
# 1438  48145     500000           0           0
# 1437  48135          0           0           0
#
#                                                   title  vote_average  \
# 58                                         Interstellar           8.1
# 78                                   Mad Max: Fury Road           7.2
# 119   Pirates of the Caribbean: The Curse of the Bla...           7.5
# 120               The Hunger Games: Mockingjay - Part 1           6.6
# ...

# %%
top_popular_movies.head(10)
# Out:
#         id     budget  popularity     revenue  \
# 58   43692  165000000         724   675120017
# 78   43724  150000000         434   378858340
# 119  43796  140000000         271   655011224
# 120  43797  125000000         206   752100229
# 45   43662  185000000         187  1004558444
# 59   43693  160000000         167   825532764
# 162  43867  108000000         167   630161890
# 5    43606  250000000         155   873260194
# 0    43597  237000000         150  2787965087
# 383  44259   63000000         146   100853753
#
#                                                  title  vote_average  \
# 58                                        Interstellar           8.1
# 78                                  Mad Max: Fury Road           7.2
# 119  Pirates of the Caribbean: The Curse of the Bla...           7.5
# 120              The Hunger Games: Mockingjay - Part 1           6.6
# 45                                     The Dark Knight           8.2
# ...

# %% [markdown]
# ##HW- make this generic, given popularity and vote_average combintion within it

# %% [markdown]
# ##Q6 - How many movies that are among top 10 popular movies are also among top 10 rated (vote_avg)?

# %%
top_10_popular_movies = movies.sort_values("popularity", ascending = False)["title"].head(10)
top_10_popular_movies
# Out:
# 58                                          Interstellar
# 78                                    Mad Max: Fury Road
# 119    Pirates of the Caribbean: The Curse of the Bla...
# 120                The Hunger Games: Mockingjay - Part 1
# 45                                       The Dark Knight
# 162                                          The Martian
# 59                                             Inception
# 5                     Batman v Superman: Dawn of Justice
# 0                                                 Avatar
# 383                                           Fight Club
# Name: title, dtype: object

# %%
top_10_rated_movies = movies.sort_values("vote_average", ascending = False)["title"].head(10)
top_10_rated_movies
# Out:
# 1284                                     Pulp Fiction
# 383                                        Fight Club
# 901                                  Schindler's List
# 459                                      Forrest Gump
# 45                                    The Dark Knight
# 917                                        GoodFellas
# 199     The Lord of the Rings: The Return of the King
# 785                                             Se7en
# 59                                          Inception
# 1326                               The Usual Suspects
# Name: title, dtype: object

# %%
#usecase of isin()
df_popularly_rated = movies[(movies["title"].isin(top_10_popular_movies)) & (movies["title"].isin(top_10_rated_movies))]
df_popularly_rated
# Out:
#         id     budget  popularity     revenue            title  vote_average  \
# 45   43662  185000000         187  1004558444  The Dark Knight           8.2
# 59   43693  160000000         167   825532764        Inception           8.1
# 383  44259   63000000         146   100853753       Fight Club           8.3
#
#      vote_count  director_id  year month        day
# 45        12002         4765  2008   Jul  Wednesday
# 59        13752         4765  2010   Jul  Wednesday
# 383        9413         4829  1999   Oct     Friday

# %% [markdown]
# ##Q: Create a new metric called revnue_per_budget revenue/budget and round it off to 2 decimal places.

# %%
def new_metric(df):
  val = np.round(df["revenue"]/df["budget"],2)
  df["revenue/budget"] = val
  return df

# %%
#using apply
movies_copy = movies[["revenue", "budget"]].apply(new_metric, axis = 1)
movies_copy.head()
# Out:
# <ipython-input-84-60f48eaaf896>:2: RuntimeWarning: divide by zero encountered in long_scalars
#   val = np.round(df["revenue"]/df["budget"],2)
# <ipython-input-84-60f48eaaf896>:2: RuntimeWarning: invalid value encountered in long_scalars
#   val = np.round(df["revenue"]/df["budget"],2)
# <ipython-input-84-60f48eaaf896>:2: RuntimeWarning: divide by zero encountered in long_scalars
#   val = np.round(df["revenue"]/df["budget"],2)
# <ipython-input-84-60f48eaaf896>:2: RuntimeWarning: invalid value encountered in long_scalars
#   val = np.round(df["revenue"]/df["budget"],2)
# <ipython-input-84-60f48eaaf896>:2: RuntimeWarning: invalid value encountered in long_scalars
#   val = np.round(df["revenue"]/df["budget"],2)
# <ipython-input-84-60f48eaaf896>:2: RuntimeWarning: divide by zero encountered in long_scalars
#   val = np.round(df["revenue"]/df["budget"],2)
# <ipython-input-84-60f48eaaf896>:2: RuntimeWarning: invalid value encountered in long_scalars
# ...

# %%
#to ignore warnings as above

import warnings
warnings.filterwarnings("ignore")

#using apply
movies_copy = movies[["revenue", "budget"]].apply(new_metric, axis = 1)
movies_copy.head()
# Out:
#         revenue       budget  revenue/budget
# 0  2.787965e+09  237000000.0           11.76
# 1  9.610000e+08  300000000.0            3.20
# 2  8.806746e+08  245000000.0            3.59
# 3  1.084939e+09  250000000.0            4.34
# 4  8.908716e+08  258000000.0            3.45

# %% [markdown]
# #Q: In which year was Christopher Nolan produced most number of movies?

# %%
data = movies.merge(directors, how='left', left_on='director_id',right_on='id')
data.drop(['director_id','id_y'],axis=1,inplace=True)

# %%
chris_movies = data[data["director_name"] == "Christopher Nolan"]

# %%
print(chris_movies)
# Out:
#        id_x     budget  popularity     revenue                  title  \
# 3     43600  250000000         112  1084939099  The Dark Knight Rises
# 45    43662  185000000         187  1004558444        The Dark Knight
# 58    43692  165000000         724   675120017           Interstellar
# 59    43693  160000000         167   825532764              Inception
# 74    43716  150000000         115   374218673          Batman Begins
# 565   44630   46000000          41   113714830               Insomnia
# 641   44793   40000000          74   109676311           The Prestige
# 1341  47170    9000000          60    39723096                Memento
#
#       vote_average  vote_count  year month        day      director_name  \
# 3              7.6        9106  2012   Jul     Monday  Christopher Nolan
# 45             8.2       12002  2008   Jul  Wednesday  Christopher Nolan
# 58             8.1       10867  2014   Nov  Wednesday  Christopher Nolan
# ...

# %%
result = chris_movies.groupby("year")["title"].count()

# %%
result
# Out:
# year
# 2000    1
# 2002    1
# 2005    1
# 2006    1
# 2008    1
# 2010    1
# 2012    1
# 2014    1
# Name: title, dtype: int64

# %%
#to make it generic
def year_wise_movies(director_name):

  dir_movies = data[data["director_name"] == director_name]

  result = dir_movies.groupby("year")["title"].count()

  return result

# %%
year_wise_movies('James Cameron')
# Out:
# year
# 1984    1
# 1986    1
# 1989    1
# 1991    1
# 1994    1
# 1997    1
# 2009    1
# Name: title, dtype: int64

# %%
data["director_name"].value_counts() #this is a great way to identify debugging logic -
#by checking code over those directors which are more likely to be among our ans
# Out:
# Steven Spielberg      26
# Martin Scorsese       19
# Clint Eastwood        19
# Woody Allen           18
# Ridley Scott          16
#                       ..
# Tim Hill               5
# Jonathan Liebesman     5
# Roman Polanski         5
# Larry Charles          5
# Nicole Holofcener      5
# Name: director_name, Length: 199, dtype: int64

# %%
year_wise_movies('Steven Spielberg')
# Out:
# year
# 1977    1
# 1979    1
# 1981    1
# 1982    1
# 1983    1
# 1984    1
# 1985    1
# 1989    1
# 1991    1
# 1993    2
# 1997    2
# 1998    1
# 2001    1
# 2002    2
# 2004    1
# 2005    2
# 2008    1
# 2011    2
# 2012    1
# 2015    1
# 2016    1
# Name: title, dtype: int64

# %%
#the idea of this session is to give such questions to users and then ask them to solve and then discuss ideas

# %%
data.groupby(["director_name","year"])["title"].count()
# Out:
# director_name  year
# Adam McKay     2004    1
#                2006    1
#                2008    1
#                2010    1
#                2013    1
#                       ..
# Zhang Yimou    2004    1
#                2006    1
#                2009    1
#                2011    1
#                2014    1
# Name: title, Length: 1398, dtype: int64

# %%
res = data.groupby(["director_name","year"])["title"].count()
res.sort_values(ascending = False)
# Out:
# director_name      year
# Michael Moore      2007    2
# Steven Soderbergh  2011    2
# Robert Zemeckis    2000    2
# John McTiernan     1999    2
# Shawn Levy         2014    2
#                           ..
# James Mangold      1999    1
#                    1997    1
# James Ivory        2009    1
#                    2005    1
# Zhang Yimou        2014    1
# Name: title, Length: 1398, dtype: int64

# %%
data[["director_name", "year"]].value_counts() #one-liner logic
# Out:
# director_name      year
# Michael Moore      2007    2
# Steven Soderbergh  2011    2
# Robert Zemeckis    2000    2
# John McTiernan     1999    2
# Shawn Levy         2014    2
#                           ..
# James Mangold      1999    1
#                    1997    1
# James Ivory        2009    1
#                    2005    1
# Zhang Yimou        2014    1
# Length: 1398, dtype: int64

# %% [markdown]
# #Q7 -In which decade, the most number of movies were produced?

# %%
data.describe() #to get an idea about the range of years we are dealing with
# Out:
#                id_x        budget   popularity       revenue  vote_average  \
# count   1465.000000  1.465000e+03  1465.000000  1.465000e+03   1465.000000
# mean   45225.191126  4.802295e+07    30.855973  1.432539e+08      6.368191
# std     1189.096396  4.935541e+07    34.845214  2.064918e+08      0.818033
# min    43597.000000  0.000000e+00     0.000000  0.000000e+00      3.000000
# 25%    44236.000000  1.400000e+07    11.000000  1.738013e+07      5.900000
# 50%    45022.000000  3.300000e+07    23.000000  7.578164e+07      6.400000
# 75%    45990.000000  6.600000e+07    41.000000  1.792469e+08      6.900000
# max    48395.000000  3.800000e+08   724.000000  2.787965e+09      8.300000
#
#          vote_count         year
# count   1465.000000  1465.000000
# mean    1146.396587  2002.615017
# std     1578.077438     8.680141
# min        1.000000  1976.000000
# 25%      216.000000  1998.000000
# 50%      571.000000  2004.000000
# 75%     1387.000000  2009.000000
# ...

# %%
#observation: we have data from 1976 to 2016 - lets create decades accordingly

# %%
bins = [1970, 1980, 1990, 2000, 2010, 2020]
labels = ["1", "2", "3", "4", "5"]

data["year_bucket"] = pd.cut(data["year"], bins = bins, labels = labels)
data
# Out:
#        id_x     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 4     43602  258000000         115   890871626
# ...     ...        ...         ...         ...
# 1460  48363          0           3      321952
# 1461  48370      27000          19     3151130
# 1462  48375          0           7           0
# 1463  48376          0           3           0
# 1464  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %%
#can - check manually

# %%
data["year_bucket"].value_counts()
# Out:
# 4    644
# 3    376
# 5    293
# 2    126
# 1     26
# Name: year_bucket, dtype: int64

# %%
#ans: bucket 4: 2000-2010 most number of movies got produced

# %% [markdown]
# #Q8- Within the decade with most number of movies, which were the top 5 contributing directors (who produced most)

# %%
data_4 = data[data["year_bucket"] == 4]
data["director_name"].value_counts().head(5)
# Out:
# Steven Spielberg    26
# Martin Scorsese     19
# Clint Eastwood      19
# Woody Allen         18
# Ridley Scott        16
# Name: director_name, dtype: int64

# %%
#missing data

# %%
data.isna().sum()
# Out:
# id_x               0
# budget             0
# popularity         0
# revenue            0
# title              0
# vote_average       0
# vote_count         0
# year               0
# month              0
# day                0
# director_name      0
# gender           124
# year_bucket        0
# dtype: int64

# %%
data["gender"].fillna("NA", inplace = True)

# %%
data["gender"].value_counts(normalize=True)*100
# Out:
# Male      89.351536
# NA         8.464164
# Female     2.184300
# Name: gender, dtype: float64

# %%
#Obs: earlier, value_counts() ignored the nulls in the gender column

# %%
#HW--> try to fill gender with M/F depending on the mode within each genre, if given (extra concept)

# %% [markdown]
# #Q11- Display movie details of only those years where number of movies produced are more than 70 (group by filter)

# %%
result = data.groupby("year").filter(lambda x: x["title"].count() > 70)

# %%
result
# Out:
#        id_x     budget  popularity     revenue  \
# 6     43607  270000000          57   391081192
# 8     43609  200000000         145  1065659812
# 18    43621  207000000          61   550000000
# 24    43630  210000000           3   459359555
# 43    43660  180000000          67   748806957
# ...     ...        ...         ...         ...
# 1342  47172    5000000          18    26888376
# 1359  47275          0           3           0
# 1365  47328    4200000          16           0
# 1373  47351    4000000          17    31584901
# 1407  47696    2000000          12     5967038
#
#                                                   title  vote_average  \
# 6                                      Superman Returns           5.4
# 8            Pirates of the Caribbean: Dead Man's Chest           7.0
# 18                                            King Kong           6.6
# 24                                X-Men: The Last Stand           6.3
# ...

# %%
#validate your answer - just to build intution

# %%
data["year"].value_counts()
#obs: only year 2005 and 2006 had more than 70 movies, 71 and 73 respectively so total rows in output should be 71+73 = 144
# Out:
# 2006    73
# 2005    71
# 2002    69
# 2008    67
# 2011    67
# 2009    66
# 1999    64
# 2010    63
# 2001    62
# 2004    61
# 2000    59
# 2003    58
# 2013    57
# 2007    54
# 2014    53
# 2012    49
# 1997    46
# 1996    46
# 1998    45
# 2015    41
# 1995    33
# 1994    31
# 2016    26
# 1992    22
# 1989    18
# 1990    18
# 1993    18
# 1985    14
# 1988    13
# 1991    12
# 1987    12
# 1986    11
# 1981    11
# 1982    10
# 1984    10
# 1983     9
# 1980     8
# 1977     6
# 1978     5
# 1979     4
# 1976     3
# Name: year, dtype: int64

# %%
data[data["year"].isin([2005,2006])]
#we still prefer group by filter logic in industry as that is more scalable - if we had 100s of such years then not possible to check manually
#in such cases we can still validate by filtering out data for some specific years and checking if it works for that or not.
# Out:
#        id_x     budget  popularity     revenue  \
# 6     43607  270000000          57   391081192
# 8     43609  200000000         145  1065659812
# 18    43621  207000000          61   550000000
# 24    43630  210000000           3   459359555
# 43    43660  180000000          67   748806957
# ...     ...        ...         ...         ...
# 1342  47172    5000000          18    26888376
# 1359  47275          0           3           0
# 1365  47328    4200000          16           0
# 1373  47351    4000000          17    31584901
# 1407  47696    2000000          12     5967038
#
#                                                   title  vote_average  \
# 6                                      Superman Returns           5.4
# 8            Pirates of the Caribbean: Dead Man's Chest           7.0
# 18                                            King Kong           6.6
# 24                                X-Men: The Last Stand           6.3
# ...
