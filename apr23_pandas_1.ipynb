# %% [markdown]
# <a href="https://colab.research.google.com/github/adityajain2407/DAV-1-apr23/blob/main/apr23_pandas_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
# !wget "https://drive.google.com/uc?export=download&id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_" -O mckinsey.csv

# %%
df = pd.read_csv("mckinsey.csv")

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head(10)
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106
# 5  Afghanistan  1977    14880372      Asia    38.438  786.113360
# 6  Afghanistan  1982    12881816      Asia    39.854  978.011439
# 7  Afghanistan  1987    13867957      Asia    40.822  852.395945
# 8  Afghanistan  1992    16317921      Asia    41.674  649.341395
# 9  Afghanistan  1997    22227415      Asia    41.763  635.341351

# %%
df.tail()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1699  Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700  Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701  Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702  Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703  Zimbabwe  2007    12311143    Africa    43.487  469.709298

# %%
df.tail(10)
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1694  Zimbabwe  1962     4277736    Africa    52.358  527.272182
# 1695  Zimbabwe  1967     4995432    Africa    53.995  569.795071
# 1696  Zimbabwe  1972     5861135    Africa    55.635  799.362176
# 1697  Zimbabwe  1977     6642107    Africa    57.674  685.587682
# 1698  Zimbabwe  1982     7636524    Africa    60.363  788.855041
# 1699  Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700  Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701  Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702  Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703  Zimbabwe  2007    12311143    Africa    43.487  469.709298

# %%
df.shape
# Out:
# (1704, 6)

# %%
rows = df.shape[0]
cols = df.shape[1]

# %%
print(rows)
# Out:
# 1704

# %%
print(cols)
# Out:
# 6

# %%
df["country"]
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
type(df["country"])
# Out:
# pandas.core.series.Series

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   country     1704 non-null   object
#  1   year        1704 non-null   int64
#  2   population  1704 non-null   int64
#  3   continent   1704 non-null   object
#  4   life_exp    1704 non-null   float64
#  5   gdp_cap     1704 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %%
#     country	  year	population	continent	life_exp	gdp_cap
# 0	Afghanistan	1952	8425333	    Asia	    28.801	  779.445314
# 1	Afghanistan	1957	9240934	    Asia	    30.332	  820.853030
# 2	Afghanistan	1962	102267083	  Asia	    31.997	  853.100710

# %%
#row-oriented approach
sample_df = pd.DataFrame(
              [['Afghanistan',1952, 8425333, 'Asia', 28.801, 779.445314 ],
              ['Afghanistan',1957, 9240934, 'Asia', 30.332, 820.853030 ],
              ['Afghanistan',1962, 102267083, 'Asia', 31.997, 853.100710 ],
               ['Afghanistan',1962, 102267083, 'Asia', 31.997, 853.100710 ]],

             columns=['country','year','population','continent','life_exp','gdp_cap']
    )

# %%
sample_df
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962   102267083      Asia    31.997  853.100710
# 3  Afghanistan  1962   102267083      Asia    31.997  853.100710

# %%
#row-oriented approach
sample_df = pd.DataFrame(
              [['Afghanistan',1952, 8425333, 'Asia', 28.801, 779.445314 ]],

             columns=['country','year','population','continent','life_exp','gdp_cap']
    )

# %%
sample_df
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314

# %%
#row-oriented approach
sample_df = pd.DataFrame(
              ['Afghanistan',1952, 8425333, 'Asia', 28.801, 779.445314 ],

             columns=['country','year','population','continent','life_exp','gdp_cap']
    )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-455c4c634548> in <cell line: 2>()
#       1 #row-oriented approach
# ----> 2 sample_df = pd.DataFrame(
#       3               ['Afghanistan',1952, 8425333, 'Asia', 28.801, 779.445314 ],
#       4
#       5              columns=['country','year','population','continent','life_exp','gdp_cap']
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     760                     )
#     761                 else:
# --> 762                     mgr = ndarray_to_mgr(
#     763                         data,
#     764                         index,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/construction.py in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     347     )
#     348
# ...

# %%
#column-oriented appraoch

df2 = pd.DataFrame(
              {'country':['Afghanistan', 'Afghanistan'],
               'year':[1952,1957],
              'population':[842533, 9240934],
               'continent':['Asia', 'Asia'],
              'life_exp':[28.801, 30.332],
               'gdp_cap':[779.445314, 820.853030]
               }
    )

df2
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952      842533      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.columns
# Out:
# Index(['country', 'year', 'population', 'continent', 'life_exp', 'gdp_cap'], dtype='object')

# %%
df.columns[0]
# Out:
# 'country'

# %%
df.columns[2]
# Out:
# 'population'

# %%
df["country"]
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
#not used - but works
df.country
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df2 = df[ ["year" , "continent"] ].head()

# %%
df2
# Out:
#    year continent
# 0  1952      Asia
# 1  1957      Asia
# 2  1962      Asia
# 3  1967      Asia
# 4  1972      Asia

# %%
#basic operations on column

# %%
unique_country = df["country"].unique() #all the unique values in a col

# %%
unique_country
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina',
#        'Australia', 'Austria', 'Bahrain', 'Bangladesh', 'Belgium',
#        'Benin', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon',
#        'Canada', 'Central African Republic', 'Chad', 'Chile', 'China',
#        'Colombia', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Czech Republic',
#        'Denmark', 'Djibouti', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Ethiopia',
#        'Finland', 'France', 'Gabon', 'Gambia', 'Germany', 'Ghana',
#        'Greece', 'Guatemala', 'Guinea', 'Guinea-Bissau', 'Haiti',
#        'Honduras', 'Hong Kong, China', 'Hungary', 'Iceland', 'India',
#        'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Israel', 'Italy',
#        'Jamaica', 'Japan', 'Jordan', 'Kenya', 'Korea, Dem. Rep.',
# ...

# %%
df["country"].nunique()
# Out:
# 142

# %%
df["country"].value_counts()
# Out:
# Afghanistan          12
# Pakistan             12
# New Zealand          12
# Nicaragua            12
# Niger                12
#                      ..
# Eritrea              12
# Equatorial Guinea    12
# El Salvador          12
# Egypt                12
# Zimbabwe             12
# Name: country, Length: 142, dtype: int64

# %%
#renaming a column

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.rename(
    {"population" : "Population",
     "country" : "Country"}
    )
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.rename(
    {"population" : "Population",
     "country" : "Country"},

    axis = 1
    )
# Out:
#           Country  year  Population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
# df.rename({"population" : "Population", "country" : "Country"}, axis = 1)

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df_renamed = df.rename({"population" : "Population", "country" : "Country"}, axis = 1)

# %%
df_renamed.head()
# Out:
#        Country  year  Population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.rename({"population" : "Population", "country" : "Country"}, axis = 1, inplace = True)

# %%
df.head()
# Out:
#        Country  year  Population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
#deleting the columns

# %%
df.drop("continent", axis = 1)
# Out:
#           Country  year  Population  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333    28.801  779.445314
# 1     Afghanistan  1957     9240934    30.332  820.853030
# 2     Afghanistan  1962    10267083    31.997  853.100710
# 3     Afghanistan  1967    11537966    34.020  836.197138
# 4     Afghanistan  1972    13079460    36.088  739.981106
# ...           ...   ...         ...       ...         ...
# 1699     Zimbabwe  1987     9216418    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    43.487  469.709298
#
# [1704 rows x 5 columns]

# %%
df.head()
# Out:
#        Country  year  Population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.drop("continent", axis = 1, inplace = True)

# %%
df.head()
# Out:
#        Country  year  Population  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333    28.801  779.445314
# 1  Afghanistan  1957     9240934    30.332  820.853030
# 2  Afghanistan  1962    10267083    31.997  853.100710
# 3  Afghanistan  1967    11537966    34.020  836.197138
# 4  Afghanistan  1972    13079460    36.088  739.981106

# %%
#way2 to drop a column

df_renamed.head()
# Out:
#        Country  year  Population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df_renamed.drop(columns = ["continent"])
# Out:
#           Country  year  Population  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333    28.801  779.445314
# 1     Afghanistan  1957     9240934    30.332  820.853030
# 2     Afghanistan  1962    10267083    31.997  853.100710
# 3     Afghanistan  1967    11537966    34.020  836.197138
# 4     Afghanistan  1972    13079460    36.088  739.981106
# ...           ...   ...         ...       ...         ...
# 1699     Zimbabwe  1987     9216418    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    43.487  469.709298
#
# [1704 rows x 5 columns]

# %%
df_renamed.head()
# Out:
#        Country  year  Population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df_renamed.drop(columns = ["continent"], inplace = True)

# %%
df_renamed.head()
# Out:
#        Country  year  Population  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333    28.801  779.445314
# 1  Afghanistan  1957     9240934    30.332  820.853030
# 2  Afghanistan  1962    10267083    31.997  853.100710
# 3  Afghanistan  1967    11537966    34.020  836.197138
# 4  Afghanistan  1972    13079460    36.088  739.981106

# %%
df_renamed.drop(columns = ["Country", "Population"], inplace = True)

# %%
df_renamed.head()
# Out:
#    year  life_exp     gdp_cap
# 0  1952    28.801  779.445314
# 1  1957    30.332  820.853030
# 2  1962    31.997  853.100710
# 3  1967    34.020  836.197138
# 4  1972    36.088  739.981106

# %%
#creating a new column

# %%
df.head()
# Out:
#        Country  year  Population  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333    28.801  779.445314
# 1  Afghanistan  1957     9240934    30.332  820.853030
# 2  Afghanistan  1962    10267083    31.997  853.100710
# 3  Afghanistan  1967    11537966    34.020  836.197138
# 4  Afghanistan  1972    13079460    36.088  739.981106

# %%
df["year+7"] = df["year"] + 7

# %%
df.head()
# Out:
#        Country  year  Population  life_exp     gdp_cap  year+7
# 0  Afghanistan  1952     8425333    28.801  779.445314    1959
# 1  Afghanistan  1957     9240934    30.332  820.853030    1964
# 2  Afghanistan  1962    10267083    31.997  853.100710    1969
# 3  Afghanistan  1967    11537966    34.020  836.197138    1974
# 4  Afghanistan  1972    13079460    36.088  739.981106    1979

# %%
df["gdp"] = df["gdp_cap"]*df["Population"]
df.head()
# Out:
#        Country  year  Population  life_exp     gdp_cap  year+7           gdp
# 0  Afghanistan  1952     8425333    28.801  779.445314    1959  6.567086e+09
# 1  Afghanistan  1957     9240934    30.332  820.853030    1964  7.585449e+09
# 2  Afghanistan  1962    10267083    31.997  853.100710    1969  8.758856e+09
# 3  Afghanistan  1967    11537966    34.020  836.197138    1974  9.648014e+09
# 4  Afghanistan  1972    13079460    36.088  739.981106    1979  9.678553e+09

# %%
df["new"] = [ i for i in range(1704)]
df
# Out:
#           Country  year  Population  life_exp     gdp_cap  year+7  \
# 0     Afghanistan  1952     8425333    28.801  779.445314    1959
# 1     Afghanistan  1957     9240934    30.332  820.853030    1964
# 2     Afghanistan  1962    10267083    31.997  853.100710    1969
# 3     Afghanistan  1967    11537966    34.020  836.197138    1974
# 4     Afghanistan  1972    13079460    36.088  739.981106    1979
# ...           ...   ...         ...       ...         ...     ...
# 1699     Zimbabwe  1987     9216418    62.351  706.157306    1994
# 1700     Zimbabwe  1992    10704340    60.377  693.420786    1999
# 1701     Zimbabwe  1997    11404948    46.809  792.449960    2004
# 1702     Zimbabwe  2002    11926563    39.989  672.038623    2009
# 1703     Zimbabwe  2007    12311143    43.487  469.709298    2014
#
#                gdp   new
# 0     6.567086e+09     0
# 1     7.585449e+09     1
# 2     8.758856e+09     2
# 3     9.648014e+09     3
# 4     9.678553e+09     4
# ...

# %%
df.drop(columns = ["year+7" , "gdp", "new"], inplace= True)
df.head()
# Out:
#        Country  year  Population  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333    28.801  779.445314
# 1  Afghanistan  1957     9240934    30.332  820.853030
# 2  Afghanistan  1962    10267083    31.997  853.100710
# 3  Afghanistan  1967    11537966    34.020  836.197138
# 4  Afghanistan  1972    13079460    36.088  739.981106

# %%
#dataframe indexing

# %%
df.head()
# Out:
#        Country  year  Population  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333    28.801  779.445314
# 1  Afghanistan  1957     9240934    30.332  820.853030
# 2  Afghanistan  1962    10267083    31.997  853.100710
# 3  Afghanistan  1967    11537966    34.020  836.197138
# 4  Afghanistan  1972    13079460    36.088  739.981106

# %%
df.columns
# Out:
# Index(['Country', 'year', 'Population', 'life_exp', 'gdp_cap'], dtype='object')

# %%
df.index.values
# Out:
# array([   0,    1,    2, ..., 1701, 1702, 1703])

# %%
n= df.shape[0]

df.index = [i for i in range(1, n+1)]

# %%
df.head()
# Out:
#        Country  year  Population  life_exp     gdp_cap
# 1  Afghanistan  1952     8425333    28.801  779.445314
# 2  Afghanistan  1957     9240934    30.332  820.853030
# 3  Afghanistan  1962    10267083    31.997  853.100710
# 4  Afghanistan  1967    11537966    34.020  836.197138
# 5  Afghanistan  1972    13079460    36.088  739.981106

# %%
sample = df.head()

# %%
sample
# Out:
#        Country  year  Population  life_exp     gdp_cap
# 1  Afghanistan  1952     8425333    28.801  779.445314
# 2  Afghanistan  1957     9240934    30.332  820.853030
# 3  Afghanistan  1962    10267083    31.997  853.100710
# 4  Afghanistan  1967    11537966    34.020  836.197138
# 5  Afghanistan  1972    13079460    36.088  739.981106

# %%
sample.index = ["a", "b", "c", "d", "e"]
sample
# Out:
#        Country  year  Population  life_exp     gdp_cap
# a  Afghanistan  1952     8425333    28.801  779.445314
# b  Afghanistan  1957     9240934    30.332  820.853030
# c  Afghanistan  1962    10267083    31.997  853.100710
# d  Afghanistan  1967    11537966    34.020  836.197138
# e  Afghanistan  1972    13079460    36.088  739.981106

# %%
ser = sample["year"]

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %%
ser
# Out:
# a    1952
# b    1957
# c    1962
# d    1967
# e    1972
# Name: year, dtype: int64

# %%
ser[2]
# Out:
# 1962

# %%
ser["c"]
# Out:
# 1962

# %%
'''
Implicit index- 0 --> iloc
Explicit index - visible --> loc
'''

# %%
df.head()
# Out:
#        Country  year  Population  life_exp     gdp_cap
# 1  Afghanistan  1952     8425333    28.801  779.445314
# 2  Afghanistan  1957     9240934    30.332  820.853030
# 3  Afghanistan  1962    10267083    31.997  853.100710
# 4  Afghanistan  1967    11537966    34.020  836.197138
# 5  Afghanistan  1972    13079460    36.088  739.981106

# %%
df.loc[1]
# Out:
# Country       Afghanistan
# year                 1952
# Population        8425333
# life_exp           28.801
# gdp_cap        779.445314
# Name: 1, dtype: object

# %%
df.iloc[0]
# Out:
# Country       Afghanistan
# year                 1952
# Population        8425333
# life_exp           28.801
# gdp_cap        779.445314
# Name: 1, dtype: object

# %%
df.head()
# Out:
#        Country  year  Population  life_exp     gdp_cap
# 1  Afghanistan  1952     8425333    28.801  779.445314
# 2  Afghanistan  1957     9240934    30.332  820.853030
# 3  Afghanistan  1962    10267083    31.997  853.100710
# 4  Afghanistan  1967    11537966    34.020  836.197138
# 5  Afghanistan  1972    13079460    36.088  739.981106

# %%
df.loc[1:3] #in slicing end is inclusive
# Out:
#        Country  year  Population  life_exp     gdp_cap
# 1  Afghanistan  1952     8425333    28.801  779.445314
# 2  Afghanistan  1957     9240934    30.332  820.853030
# 3  Afghanistan  1962    10267083    31.997  853.100710

# %%
df.iloc[1:3] #end index is exclusive in slicing using iloc
# Out:
#        Country  year  Population  life_exp    gdp_cap
# 2  Afghanistan  1957     9240934    30.332  820.85303
# 3  Afghanistan  1962    10267083    31.997  853.10071

# %%
df.head()
# Out:
#        Country  year  Population  life_exp     gdp_cap
# 1  Afghanistan  1952     8425333    28.801  779.445314
# 2  Afghanistan  1957     9240934    30.332  820.853030
# 3  Afghanistan  1962    10267083    31.997  853.100710
# 4  Afghanistan  1967    11537966    34.020  836.197138
# 5  Afghanistan  1972    13079460    36.088  739.981106

# %%
df.head(15)
# Out:
#         Country  year  Population  life_exp      gdp_cap
# 1   Afghanistan  1952     8425333    28.801   779.445314
# 2   Afghanistan  1957     9240934    30.332   820.853030
# 3   Afghanistan  1962    10267083    31.997   853.100710
# 4   Afghanistan  1967    11537966    34.020   836.197138
# 5   Afghanistan  1972    13079460    36.088   739.981106
# 6   Afghanistan  1977    14880372    38.438   786.113360
# 7   Afghanistan  1982    12881816    39.854   978.011439
# 8   Afghanistan  1987    13867957    40.822   852.395945
# 9   Afghanistan  1992    16317921    41.674   649.341395
# 10  Afghanistan  1997    22227415    41.763   635.341351
# 11  Afghanistan  2002    25268405    42.129   726.734055
# 12  Afghanistan  2007    31889923    43.828   974.580338
# 13      Albania  1952     1282697    55.230  1601.056136
# 14      Albania  1957     1476505    59.280  1942.284244
# 15      Albania  1962     1728137    64.820  2312.888958

# %%
df.iloc[ [1, 10] ] #accessing multiple rows
# Out:
#         Country  year  Population  life_exp     gdp_cap
# 2   Afghanistan  1957     9240934    30.332  820.853030
# 11  Afghanistan  2002    25268405    42.129  726.734055

# %%
df
# Out:
#           Country  year  Population  life_exp     gdp_cap
# 1     Afghanistan  1952     8425333    28.801  779.445314
# 2     Afghanistan  1957     9240934    30.332  820.853030
# 3     Afghanistan  1962    10267083    31.997  853.100710
# 4     Afghanistan  1967    11537966    34.020  836.197138
# 5     Afghanistan  1972    13079460    36.088  739.981106
# ...           ...   ...         ...       ...         ...
# 1700     Zimbabwe  1987     9216418    62.351  706.157306
# 1701     Zimbabwe  1992    10704340    60.377  693.420786
# 1702     Zimbabwe  1997    11404948    46.809  792.449960
# 1703     Zimbabwe  2002    11926563    39.989  672.038623
# 1704     Zimbabwe  2007    12311143    43.487  469.709298
#
# [1704 rows x 5 columns]

# %%
df.loc[-1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: -1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df.iloc[-1] #last row
# Out:
# Country         Zimbabwe
# year                2007
# Population      12311143
# life_exp          43.487
# gdp_cap       469.709298
# Name: 1704, dtype: object

# %%
df.head()
# Out:
#        Country  year  Population  life_exp     gdp_cap
# 1  Afghanistan  1952     8425333    28.801  779.445314
# 2  Afghanistan  1957     9240934    30.332  820.853030
# 3  Afghanistan  1962    10267083    31.997  853.100710
# 4  Afghanistan  1967    11537966    34.020  836.197138
# 5  Afghanistan  1972    13079460    36.088  739.981106

# %%
temp = df.set_index("Country")
temp
# Out:
#              year  Population  life_exp     gdp_cap
# Country
# Afghanistan  1952     8425333    28.801  779.445314
# Afghanistan  1957     9240934    30.332  820.853030
# Afghanistan  1962    10267083    31.997  853.100710
# Afghanistan  1967    11537966    34.020  836.197138
# Afghanistan  1972    13079460    36.088  739.981106
# ...           ...         ...       ...         ...
# Zimbabwe     1987     9216418    62.351  706.157306
# Zimbabwe     1992    10704340    60.377  693.420786
# Zimbabwe     1997    11404948    46.809  792.449960
# Zimbabwe     2002    11926563    39.989  672.038623
# Zimbabwe     2007    12311143    43.487  469.709298
#
# [1704 rows x 4 columns]

# %%
temp.head()
# Out:
#              year  Population  life_exp     gdp_cap
# Country
# Afghanistan  1952     8425333    28.801  779.445314
# Afghanistan  1957     9240934    30.332  820.853030
# Afghanistan  1962    10267083    31.997  853.100710
# Afghanistan  1967    11537966    34.020  836.197138
# Afghanistan  1972    13079460    36.088  739.981106

# %%
df.head()
# Out:
#        Country  year  Population  life_exp     gdp_cap
# 1  Afghanistan  1952     8425333    28.801  779.445314
# 2  Afghanistan  1957     9240934    30.332  820.853030
# 3  Afghanistan  1962    10267083    31.997  853.100710
# 4  Afghanistan  1967    11537966    34.020  836.197138
# 5  Afghanistan  1972    13079460    36.088  739.981106

# %%
temp.loc["Afghanistan"]
# Out:
#              year  Population  life_exp     gdp_cap
# Country
# Afghanistan  1952     8425333    28.801  779.445314
# Afghanistan  1957     9240934    30.332  820.853030
# Afghanistan  1962    10267083    31.997  853.100710
# Afghanistan  1967    11537966    34.020  836.197138
# Afghanistan  1972    13079460    36.088  739.981106
# Afghanistan  1977    14880372    38.438  786.113360
# Afghanistan  1982    12881816    39.854  978.011439
# Afghanistan  1987    13867957    40.822  852.395945
# Afghanistan  1992    16317921    41.674  649.341395
# Afghanistan  1997    22227415    41.763  635.341351
# Afghanistan  2002    25268405    42.129  726.734055
# Afghanistan  2007    31889923    43.828  974.580338

# %%
temp.head()
# Out:
#              year  Population  life_exp     gdp_cap
# Country
# Afghanistan  1952     8425333    28.801  779.445314
# Afghanistan  1957     9240934    30.332  820.853030
# Afghanistan  1962    10267083    31.997  853.100710
# Afghanistan  1967    11537966    34.020  836.197138
# Afghanistan  1972    13079460    36.088  739.981106

# %%
df.head()
# Out:
#        Country  year  Population  life_exp     gdp_cap
# 1  Afghanistan  1952     8425333    28.801  779.445314
# 2  Afghanistan  1957     9240934    30.332  820.853030
# 3  Afghanistan  1962    10267083    31.997  853.100710
# 4  Afghanistan  1967    11537966    34.020  836.197138
# 5  Afghanistan  1972    13079460    36.088  739.981106

# %%
df.reset_index()
# Out:
#       index      Country  year  Population  life_exp     gdp_cap
# 0         1  Afghanistan  1952     8425333    28.801  779.445314
# 1         2  Afghanistan  1957     9240934    30.332  820.853030
# 2         3  Afghanistan  1962    10267083    31.997  853.100710
# 3         4  Afghanistan  1967    11537966    34.020  836.197138
# 4         5  Afghanistan  1972    13079460    36.088  739.981106
# ...     ...          ...   ...         ...       ...         ...
# 1699   1700     Zimbabwe  1987     9216418    62.351  706.157306
# 1700   1701     Zimbabwe  1992    10704340    60.377  693.420786
# 1701   1702     Zimbabwe  1997    11404948    46.809  792.449960
# 1702   1703     Zimbabwe  2002    11926563    39.989  672.038623
# 1703   1704     Zimbabwe  2007    12311143    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.reset_index(drop = True)
# Out:
#           Country  year  Population  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333    28.801  779.445314
# 1     Afghanistan  1957     9240934    30.332  820.853030
# 2     Afghanistan  1962    10267083    31.997  853.100710
# 3     Afghanistan  1967    11537966    34.020  836.197138
# 4     Afghanistan  1972    13079460    36.088  739.981106
# ...           ...   ...         ...       ...         ...
# 1699     Zimbabwe  1987     9216418    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    43.487  469.709298
#
# [1704 rows x 5 columns]

# %%
df.head()
# Out:
#        Country  year  Population  life_exp     gdp_cap
# 1  Afghanistan  1952     8425333    28.801  779.445314
# 2  Afghanistan  1957     9240934    30.332  820.853030
# 3  Afghanistan  1962    10267083    31.997  853.100710
# 4  Afghanistan  1967    11537966    34.020  836.197138
# 5  Afghanistan  1972    13079460    36.088  739.981106

# %%
df.reset_index(drop = True, inplace = True)

# %%
df.head()
# Out:
#        Country  year  Population  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333    28.801  779.445314
# 1  Afghanistan  1957     9240934    30.332  820.853030
# 2  Afghanistan  1962    10267083    31.997  853.100710
# 3  Afghanistan  1967    11537966    34.020  836.197138
# 4  Afghanistan  1972    13079460    36.088  739.981106

# %%
#hw - try reseting for temp

# %%
df_sample = df.head()

# %%
df_sample
# Out:
#        Country  year  Population  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333    28.801  779.445314
# 1  Afghanistan  1957     9240934    30.332  820.853030
# 2  Afghanistan  1962    10267083    31.997  853.100710
# 3  Afghanistan  1967    11537966    34.020  836.197138
# 4  Afghanistan  1972    13079460    36.088  739.981106

# %%
df_sample.drop(columns = ["year"])
# Out:
#        Country  Population  life_exp     gdp_cap
# 0  Afghanistan     8425333    28.801  779.445314
# 1  Afghanistan     9240934    30.332  820.853030
# 2  Afghanistan    10267083    31.997  853.100710
# 3  Afghanistan    11537966    34.020  836.197138
# 4  Afghanistan    13079460    36.088  739.981106

# %%
df_sample
# Out:
#        Country  year  Population  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333    28.801  779.445314
# 1  Afghanistan  1957     9240934    30.332  820.853030
# 2  Afghanistan  1962    10267083    31.997  853.100710
# 3  Afghanistan  1967    11537966    34.020  836.197138
# 4  Afghanistan  1972    13079460    36.088  739.981106

# %%
df_sample = df_sample.drop(columns = ["year"])

# %%
df_sample
# Out:
#        Country  Population  life_exp     gdp_cap
# 0  Afghanistan     8425333    28.801  779.445314
# 1  Afghanistan     9240934    30.332  820.853030
# 2  Afghanistan    10267083    31.997  853.100710
# 3  Afghanistan    11537966    34.020  836.197138
# 4  Afghanistan    13079460    36.088  739.981106
