# %% [markdown]
# <a href="https://colab.research.google.com/github/adityajain2407/DAV-1-apr23/blob/main/pandas_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
# !gdown 1s2TkjSpzNc4SyxqRrQleZyDIHlc7bxnd
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1s2TkjSpzNc4SyxqRrQleZyDIHlc7bxnd
# To: /content/movies.csv
# 100% 112k/112k [00:00<00:00, 114MB/s]

# %%
# !gdown 1Ws-_s1fHZ9nHfGLVUQurbHDvStePlEJm
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1Ws-_s1fHZ9nHfGLVUQurbHDvStePlEJm
# To: /content/directors.csv
# 100% 65.4k/65.4k [00:00<00:00, 71.5MB/s]

# %%
movies = pd.read_csv("movies.csv")
directors = pd.read_csv("directors.csv")

# %%
movies.head()
# Out:
#    Unnamed: 0     id     budget  popularity     revenue  \
# 0           0  43597  237000000         150  2787965087
# 1           1  43598  300000000         139   961000000
# 2           2  43599  245000000         107   880674609
# 3           3  43600  250000000         112  1084939099
# 4           5  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day
# 0         4762  2009   Dec  Thursday
# 1         4763  2007   May  Saturday
# 2         4764  2015   Oct    Monday
# 3         4765  2012   Jul    Monday
# 4         4767  2007   May   Tuesday

# %%
movies.drop(columns = ["Unnamed: 0"] , inplace = True)

# %%
movies.head()
# Out:
#       id     budget  popularity     revenue  \
# 0  43597  237000000         150  2787965087
# 1  43598  300000000         139   961000000
# 2  43599  245000000         107   880674609
# 3  43600  250000000         112  1084939099
# 4  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day
# 0         4762  2009   Dec  Thursday
# 1         4763  2007   May  Saturday
# 2         4764  2015   Oct    Monday
# 3         4765  2012   Jul    Monday
# 4         4767  2007   May   Tuesday

# %%
directors.drop(columns = ["Unnamed: 0"] , inplace = True)

# %%
directors.head()
# Out:
#        director_name    id gender
# 0      James Cameron  4762   Male
# 1     Gore Verbinski  4763   Male
# 2         Sam Mendes  4764   Male
# 3  Christopher Nolan  4765   Male
# 4     Andrew Stanton  4766   Male

# %%
data = movies.merge(directors, how = "left", left_on = "director_id", right_on = "id")

# %%
data.head()
# Out:
#     id_x     budget  popularity     revenue  \
# 0  43597  237000000         150  2787965087
# 1  43598  300000000         139   961000000
# 2  43599  245000000         107   880674609
# 3  43600  250000000         112  1084939099
# 4  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day      director_name  id_y gender
# 0         4762  2009   Dec  Thursday      James Cameron  4762   Male
# 1         4763  2007   May  Saturday     Gore Verbinski  4763   Male
# 2         4764  2015   Oct    Monday         Sam Mendes  4764   Male
# 3         4765  2012   Jul    Monday  Christopher Nolan  4765   Male
# 4         4767  2007   May   Tuesday          Sam Raimi  4767   Male

# %%
data.drop(columns = ["director_id", "id_y"], inplace = True)

# %%
data.head()
# Out:
#     id_x     budget  popularity     revenue  \
# 0  43597  237000000         150  2787965087
# 1  43598  300000000         139   961000000
# 2  43599  245000000         107   880674609
# 3  43600  250000000         112  1084939099
# 4  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  year  \
# 0                                    Avatar           7.2       11800  2009
# 1  Pirates of the Caribbean: At World's End           6.9        4500  2007
# 2                                   Spectre           6.3        4466  2015
# 3                     The Dark Knight Rises           7.6        9106  2012
# 4                              Spider-Man 3           5.9        3576  2007
#
#   month       day      director_name gender
# 0   Dec  Thursday      James Cameron   Male
# 1   May  Saturday     Gore Verbinski   Male
# 2   Oct    Monday         Sam Mendes   Male
# 3   Jul    Monday  Christopher Nolan   Male
# 4   May   Tuesday          Sam Raimi   Male

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1465 entries, 0 to 1464
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id_x           1465 non-null   int64
#  1   budget         1465 non-null   int64
#  2   popularity     1465 non-null   int64
#  3   revenue        1465 non-null   int64
#  4   title          1465 non-null   object
#  5   vote_average   1465 non-null   float64
#  6   vote_count     1465 non-null   int64
#  7   year           1465 non-null   int64
#  8   month          1465 non-null   object
#  9   day            1465 non-null   object
#  10  director_name  1465 non-null   object
#  11  gender         1341 non-null   object
# dtypes: float64(1), int64(6), object(5)
# memory usage: 148.8+ KB

# %%
data.describe()
# Out:
#                id_x        budget   popularity       revenue  vote_average  \
# count   1465.000000  1.465000e+03  1465.000000  1.465000e+03   1465.000000
# mean   45225.191126  4.802295e+07    30.855973  1.432539e+08      6.368191
# std     1189.096396  4.935541e+07    34.845214  2.064918e+08      0.818033
# min    43597.000000  0.000000e+00     0.000000  0.000000e+00      3.000000
# 25%    44236.000000  1.400000e+07    11.000000  1.738013e+07      5.900000
# 50%    45022.000000  3.300000e+07    23.000000  7.578164e+07      6.400000
# 75%    45990.000000  6.600000e+07    41.000000  1.792469e+08      6.900000
# max    48395.000000  3.800000e+08   724.000000  2.787965e+09      8.300000
#
#          vote_count         year
# count   1465.000000  1465.000000
# mean    1146.396587  2002.615017
# std     1578.077438     8.680141
# min        1.000000  1976.000000
# 25%      216.000000  1998.000000
# 50%      571.000000  2004.000000
# 75%     1387.000000  2009.000000
# max    13752.000000  2016.000000

# %%
data.head()
# Out:
#     id_x     budget  popularity     revenue  \
# 0  43597  237000000         150  2787965087
# 1  43598  300000000         139   961000000
# 2  43599  245000000         107   880674609
# 3  43600  250000000         112  1084939099
# 4  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  year  \
# 0                                    Avatar           7.2       11800  2009
# 1  Pirates of the Caribbean: At World's End           6.9        4500  2007
# 2                                   Spectre           6.3        4466  2015
# 3                     The Dark Knight Rises           7.6        9106  2012
# 4                              Spider-Man 3           5.9        3576  2007
#
#   month       day      director_name gender
# 0   Dec  Thursday      James Cameron   Male
# 1   May  Saturday     Gore Verbinski   Male
# 2   Oct    Monday         Sam Mendes   Male
# 3   Jul    Monday  Christopher Nolan   Male
# 4   May   Tuesday          Sam Raimi   Male

# %%
data["revenue"] = (data["revenue"]/1000000).round(2)
data.head()
# Out:
#     id_x     budget  popularity  revenue  \
# 0  43597  237000000         150  2787.97
# 1  43598  300000000         139   961.00
# 2  43599  245000000         107   880.67
# 3  43600  250000000         112  1084.94
# 4  43602  258000000         115   890.87
#
#                                       title  vote_average  vote_count  year  \
# 0                                    Avatar           7.2       11800  2009
# 1  Pirates of the Caribbean: At World's End           6.9        4500  2007
# 2                                   Spectre           6.3        4466  2015
# 3                     The Dark Knight Rises           7.6        9106  2012
# 4                              Spider-Man 3           5.9        3576  2007
#
#   month       day      director_name gender
# 0   Dec  Thursday      James Cameron   Male
# 1   May  Saturday     Gore Verbinski   Male
# 2   Oct    Monday         Sam Mendes   Male
# 3   Jul    Monday  Christopher Nolan   Male
# 4   May   Tuesday          Sam Raimi   Male

# %%
data["budget"] = (data["budget"]/1000000).round(2)
data.head()
# Out:
#     id_x  budget  popularity  revenue  \
# 0  43597   237.0         150  2787.97
# 1  43598   300.0         139   961.00
# 2  43599   245.0         107   880.67
# 3  43600   250.0         112  1084.94
# 4  43602   258.0         115   890.87
#
#                                       title  vote_average  vote_count  year  \
# 0                                    Avatar           7.2       11800  2009
# 1  Pirates of the Caribbean: At World's End           6.9        4500  2007
# 2                                   Spectre           6.3        4466  2015
# 3                     The Dark Knight Rises           7.6        9106  2012
# 4                              Spider-Man 3           5.9        3576  2007
#
#   month       day      director_name gender
# 0   Dec  Thursday      James Cameron   Male
# 1   May  Saturday     Gore Verbinski   Male
# 2   Oct    Monday         Sam Mendes   Male
# 3   Jul    Monday  Christopher Nolan   Male
# 4   May   Tuesday          Sam Raimi   Male

# %%
data["vote_average"] > 7
# Out:
# 0        True
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 1460     True
# 1461     True
# 1462    False
# 1463    False
# 1464    False
# Name: vote_average, Length: 1465, dtype: bool

# %%
data.loc[ data["vote_average"]  > 7]
# Out:
#        id_x  budget  popularity  revenue  \
# 0     43597  237.00         150  2787.97
# 3     43600  250.00         112  1084.94
# 14    43616  250.00         120   956.02
# 16    43619  250.00          94   958.40
# 19    43622  200.00         100  1845.03
# ...     ...     ...         ...      ...
# 1456  48321    0.01          20     7.00
# 1457  48323    0.00           5     0.00
# 1458  48335    0.06          27     3.22
# 1460  48363    0.00           3     0.32
# 1461  48370    0.03          19     3.15
#
#                                           title  vote_average  vote_count  \
# 0                                        Avatar           7.2       11800
# 3                         The Dark Knight Rises           7.6        9106
# 14    The Hobbit: The Battle of the Five Armies           7.1        4760
# 16          The Hobbit: The Desolation of Smaug           7.6        4524
# 19                                      Titanic           7.5        7562
# ...                                         ...           ...         ...
# 1456                                 Eraserhead           7.5         485
# 1457                                 The Mighty           7.1          51
# 1458                                         Pi           7.1         586
# 1460                             The Last Waltz           7.9          64
# 1461                                     Clerks           7.4         755
#
#       year month        day      director_name gender
# 0     2009   Dec   Thursday      James Cameron   Male
# 3     2012   Jul     Monday  Christopher Nolan   Male
# 14    2014   Dec  Wednesday      Peter Jackson   Male
# 16    2013   Dec  Wednesday      Peter Jackson   Male
# 19    1997   Nov    Tuesday      James Cameron   Male
# ...    ...   ...        ...                ...    ...
# 1456  1977   Mar   Saturday        David Lynch   Male
# 1457  1998   Oct     Friday      Peter Chelsom   Male
# 1458  1998   Jul     Friday   Darren Aronofsky   Male
# 1460  1978   May     Monday    Martin Scorsese   Male
# 1461  1994   Sep    Tuesday        Kevin Smith   Male
#
# [301 rows x 12 columns]

# %%
data.shape
# Out:
# (1465, 12)

# %%
#display the title and director_name of the movies with vote_avg > 7

# %%
df2 = data.loc[ data["vote_average"]  > 7]

# %%
df2
# Out:
#        id_x  budget  popularity  revenue  \
# 0     43597  237.00         150  2787.97
# 3     43600  250.00         112  1084.94
# 14    43616  250.00         120   956.02
# 16    43619  250.00          94   958.40
# 19    43622  200.00         100  1845.03
# ...     ...     ...         ...      ...
# 1456  48321    0.01          20     7.00
# 1457  48323    0.00           5     0.00
# 1458  48335    0.06          27     3.22
# 1460  48363    0.00           3     0.32
# 1461  48370    0.03          19     3.15
#
#                                           title  vote_average  vote_count  \
# 0                                        Avatar           7.2       11800
# 3                         The Dark Knight Rises           7.6        9106
# 14    The Hobbit: The Battle of the Five Armies           7.1        4760
# 16          The Hobbit: The Desolation of Smaug           7.6        4524
# 19                                      Titanic           7.5        7562
# ...                                         ...           ...         ...
# 1456                                 Eraserhead           7.5         485
# 1457                                 The Mighty           7.1          51
# 1458                                         Pi           7.1         586
# 1460                             The Last Waltz           7.9          64
# 1461                                     Clerks           7.4         755
#
#       year month        day      director_name gender
# 0     2009   Dec   Thursday      James Cameron   Male
# 3     2012   Jul     Monday  Christopher Nolan   Male
# 14    2014   Dec  Wednesday      Peter Jackson   Male
# 16    2013   Dec  Wednesday      Peter Jackson   Male
# 19    1997   Nov    Tuesday      James Cameron   Male
# ...    ...   ...        ...                ...    ...
# 1456  1977   Mar   Saturday        David Lynch   Male
# 1457  1998   Oct     Friday      Peter Chelsom   Male
# 1458  1998   Jul     Friday   Darren Aronofsky   Male
# 1460  1978   May     Monday    Martin Scorsese   Male
# 1461  1994   Sep    Tuesday        Kevin Smith   Male
#
# [301 rows x 12 columns]

# %%
df2.loc[:, ["title", "director_name"]]
# Out:
#                                           title      director_name
# 0                                        Avatar      James Cameron
# 3                         The Dark Knight Rises  Christopher Nolan
# 14    The Hobbit: The Battle of the Five Armies      Peter Jackson
# 16          The Hobbit: The Desolation of Smaug      Peter Jackson
# 19                                      Titanic      James Cameron
# ...                                         ...                ...
# 1456                                 Eraserhead        David Lynch
# 1457                                 The Mighty      Peter Chelsom
# 1458                                         Pi   Darren Aronofsky
# 1460                             The Last Waltz    Martin Scorsese
# 1461                                     Clerks        Kevin Smith
#
# [301 rows x 2 columns]

# %%
data.loc[ data["vote_average"]  > 7, ["title", "director_name"]]
# Out:
#                                           title      director_name
# 0                                        Avatar      James Cameron
# 3                         The Dark Knight Rises  Christopher Nolan
# 14    The Hobbit: The Battle of the Five Armies      Peter Jackson
# 16          The Hobbit: The Desolation of Smaug      Peter Jackson
# 19                                      Titanic      James Cameron
# ...                                         ...                ...
# 1456                                 Eraserhead        David Lynch
# 1457                                 The Mighty      Peter Chelsom
# 1458                                         Pi   Darren Aronofsky
# 1460                             The Last Waltz    Martin Scorsese
# 1461                                     Clerks        Kevin Smith
#
# [301 rows x 2 columns]

# %%
#Display only those movies where the vote_avg > 7 and they have been released in or after 2015

# %%
data.head()
# Out:
#     id_x  budget  popularity  revenue  \
# 0  43597   237.0         150  2787.97
# 1  43598   300.0         139   961.00
# 2  43599   245.0         107   880.67
# 3  43600   250.0         112  1084.94
# 4  43602   258.0         115   890.87
#
#                                       title  vote_average  vote_count  year  \
# 0                                    Avatar           7.2       11800  2009
# 1  Pirates of the Caribbean: At World's End           6.9        4500  2007
# 2                                   Spectre           6.3        4466  2015
# 3                     The Dark Knight Rises           7.6        9106  2012
# 4                              Spider-Man 3           5.9        3576  2007
#
#   month       day      director_name gender
# 0   Dec  Thursday      James Cameron   Male
# 1   May  Saturday     Gore Verbinski   Male
# 2   Oct    Monday         Sam Mendes   Male
# 3   Jul    Monday  Christopher Nolan   Male
# 4   May   Tuesday          Sam Raimi   Male

# %%
data.loc[ (data["vote_average"] > 7) & (data["year"] >= 2015) ]
# Out:
#        id_x  budget  popularity  revenue                    title  \
# 30    43641   190.0         102  1506.25                Furious 7
# 78    43724   150.0         434   378.86       Mad Max: Fury Road
# 106   43773   135.0         100   532.95             The Revenant
# 162   43867   108.0         167   630.16              The Martian
# 312   44128    75.0          48   108.15  The Man from U.N.C.L.E.
# 394   44281    44.0          68   155.76        The Hateful Eight
# 625   44770    35.0          53   194.56               The Intern
# 635   44784    40.0          48   165.48          Bridge of Spies
# 808   45194    30.0          65    91.71                 Southpaw
# 833   45293    28.0          61   201.63   Straight Outta Compton
# 839   45301    28.0          57   133.35            The Big Short
# 1344  47181     5.0          22    24.80                     Race
#
#       vote_average  vote_count  year month        day  \
# 30             7.3        4176  2015   Apr  Wednesday
# 78             7.2        9427  2015   May  Wednesday
# 106            7.3        6396  2015   Dec     Friday
# 162            7.6        7268  2015   Sep  Wednesday
# 312            7.1        2265  2015   Aug   Thursday
# 394            7.6        4274  2015   Dec     Friday
# 625            7.1        1881  2015   Sep   Thursday
# 635            7.2        2583  2015   Oct   Thursday
# 808            7.3        2067  2015   Jun     Monday
# 833            7.7        1355  2015   Aug   Thursday
# 839            7.3        2607  2015   Dec     Friday
# 1344           7.1         478  2016   Feb     Friday
#
#                     director_name  gender
# 30                      James Wan    Male
# 78                  George Miller    Male
# 106   Alejandro González Iñárritu    Male
# 162                  Ridley Scott    Male
# 312                   Guy Ritchie    Male
# 394             Quentin Tarantino    Male
# 625                  Nancy Meyers  Female
# 635              Steven Spielberg    Male
# 808                 Antoine Fuqua    Male
# 833                  F. Gary Gray    Male
# 839                    Adam McKay    Male
# 1344              Stephen Hopkins    Male

# %%
'''
and --> &
or --> |
'''
# Out:
# '\nand --> &\nor --> |\n'

# %%
#Display those rows where movie has been released on Fri or Sat

# %%
data.loc[ (data["day"] == "Friday") | (data["day"] == "Saturday")]
# Out:
#        id_x  budget  popularity  revenue  \
# 1     43598  300.00         139   961.00
# 12    43614  380.00         135  1045.71
# 22    43627  200.00          35   783.77
# 25    43632  150.00          21   836.30
# 40    43656  200.00          45   769.65
# ...     ...     ...         ...      ...
# 1457  48323    0.00           5     0.00
# 1458  48335    0.06          27     3.22
# 1462  48375    0.00           7     0.00
# 1463  48376    0.00           3     0.00
# 1464  48395    0.22          14     2.04
#
#                                             title  vote_average  vote_count  \
# 1        Pirates of the Caribbean: At World's End           6.9        4500
# 12    Pirates of the Caribbean: On Stranger Tides           6.4        4948
# 22                                   Spider-Man 2           6.7        4321
# 25            Transformers: Revenge of the Fallen           6.0        3138
# 40                                           2012           5.6        4903
# ...                                           ...           ...         ...
# 1457                                   The Mighty           7.1          51
# 1458                                           Pi           7.1         586
# 1462                                      Rampage           6.0         131
# 1463                                      Slacker           6.4          77
# 1464                                  El Mariachi           6.6         238
#
#       year month       day      director_name gender
# 1     2007   May  Saturday     Gore Verbinski   Male
# 12    2011   May  Saturday       Rob Marshall   Male
# 22    2004   Jun    Friday          Sam Raimi   Male
# 25    2009   Jun    Friday        Michael Bay   Male
# 40    2009   Oct  Saturday    Roland Emmerich   Male
# ...    ...   ...       ...                ...    ...
# 1457  1998   Oct    Friday      Peter Chelsom   Male
# 1458  1998   Jul    Friday   Darren Aronofsky   Male
# 1462  2009   Aug    Friday           Uwe Boll   Male
# 1463  1990   Jul    Friday  Richard Linklater   Male
# 1464  1992   Sep    Friday   Robert Rodriguez    NaN
#
# [701 rows x 12 columns]

# %%
#The more the popularity score, the more popular the movie is:
'''
Display the rows of the 5 most popular movies
'''
# Out:
# '\nDisplay the rows of the 5 most popular movies\n'

# %%
data.head()
# Out:
#     id_x  budget  popularity  revenue  \
# 0  43597   237.0         150  2787.97
# 1  43598   300.0         139   961.00
# 2  43599   245.0         107   880.67
# 3  43600   250.0         112  1084.94
# 4  43602   258.0         115   890.87
#
#                                       title  vote_average  vote_count  year  \
# 0                                    Avatar           7.2       11800  2009
# 1  Pirates of the Caribbean: At World's End           6.9        4500  2007
# 2                                   Spectre           6.3        4466  2015
# 3                     The Dark Knight Rises           7.6        9106  2012
# 4                              Spider-Man 3           5.9        3576  2007
#
#   month       day      director_name gender
# 0   Dec  Thursday      James Cameron   Male
# 1   May  Saturday     Gore Verbinski   Male
# 2   Oct    Monday         Sam Mendes   Male
# 3   Jul    Monday  Christopher Nolan   Male
# 4   May   Tuesday          Sam Raimi   Male

# %%
df2 = data.sort_values(["popularity"], ascending = False)

# %%
df2
# Out:
#        id_x  budget  popularity  revenue  \
# 58    43692   165.0         724   675.12
# 78    43724   150.0         434   378.86
# 119   43796   140.0         271   655.01
# 120   43797   125.0         206   752.10
# 45    43662   185.0         187  1004.56
# ...     ...     ...         ...      ...
# 1437  48135     0.0           0     0.00
# 1448  48233     0.0           0     0.00
# 1438  48145     0.5           0     0.00
# 1378  47387     0.0           0     0.00
# 1440  48155     0.0           0     0.00
#
#                                                   title  vote_average  \
# 58                                         Interstellar           8.1
# 78                                   Mad Max: Fury Road           7.2
# 119   Pirates of the Caribbean: The Curse of the Bla...           7.5
# 120               The Hunger Games: Mockingjay - Part 1           6.6
# 45                                      The Dark Knight           8.2
# ...                                                 ...           ...
# 1437                                 Finishing The Game           4.9
# 1448                                       Chuck & Buck           5.7
# 1438                            Everything Put Together           5.0
# 1378                               An Everlasting Piece           6.0
# 1440                     Alleluia! The Devil's Carnival           6.0
#
#       vote_count  year month        day        director_name gender
# 58         10867  2014   Nov  Wednesday    Christopher Nolan   Male
# 78          9427  2015   May  Wednesday        George Miller   Male
# 119         6985  2003   Jul  Wednesday       Gore Verbinski   Male
# 120         5584  2014   Nov    Tuesday     Francis Lawrence   Male
# 45         12002  2008   Jul  Wednesday    Christopher Nolan   Male
# ...          ...   ...   ...        ...                  ...    ...
# 1437           8  2007   Jan     Sunday           Justin Lin    NaN
# 1448          16  2000   Jan     Friday        Miguel Arteta   Male
# 1438           2  2001   Nov     Friday         Marc Forster   Male
# 1378           1  2000   Dec     Friday       Barry Levinson   Male
# 1440           2  2016   Mar    Tuesday  Darren Lynn Bousman   Male
#
# [1465 rows x 12 columns]

# %%
ans = df2.head(5)

# %%
ans
# Out:
#       id_x  budget  popularity  revenue  \
# 58   43692   165.0         724   675.12
# 78   43724   150.0         434   378.86
# 119  43796   140.0         271   655.01
# 120  43797   125.0         206   752.10
# 45   43662   185.0         187  1004.56
#
#                                                  title  vote_average  \
# 58                                        Interstellar           8.1
# 78                                  Mad Max: Fury Road           7.2
# 119  Pirates of the Caribbean: The Curse of the Bla...           7.5
# 120              The Hunger Games: Mockingjay - Part 1           6.6
# 45                                     The Dark Knight           8.2
#
#      vote_count  year month        day      director_name gender
# 58        10867  2014   Nov  Wednesday  Christopher Nolan   Male
# 78         9427  2015   May  Wednesday      George Miller   Male
# 119        6985  2003   Jul  Wednesday     Gore Verbinski   Male
# 120        5584  2014   Nov    Tuesday   Francis Lawrence   Male
# 45        12002  2008   Jul  Wednesday  Christopher Nolan   Male

# %%
df2 = data.sort_values(["popularity"], ascending = False).head(5)

# %%
df2
# Out:
#       id_x  budget  popularity  revenue  \
# 58   43692   165.0         724   675.12
# 78   43724   150.0         434   378.86
# 119  43796   140.0         271   655.01
# 120  43797   125.0         206   752.10
# 45   43662   185.0         187  1004.56
#
#                                                  title  vote_average  \
# 58                                        Interstellar           8.1
# 78                                  Mad Max: Fury Road           7.2
# 119  Pirates of the Caribbean: The Curse of the Bla...           7.5
# 120              The Hunger Games: Mockingjay - Part 1           6.6
# 45                                     The Dark Knight           8.2
#
#      vote_count  year month        day      director_name gender
# 58        10867  2014   Nov  Wednesday  Christopher Nolan   Male
# 78         9427  2015   May  Wednesday      George Miller   Male
# 119        6985  2003   Jul  Wednesday     Gore Verbinski   Male
# 120        5584  2014   Nov    Tuesday   Francis Lawrence   Male
# 45        12002  2008   Jul  Wednesday  Christopher Nolan   Male

# %%
#Display the 10 most popular movies

# %%
df2 = data.sort_values(["popularity"], ascending = False).head(10)

# %%
df2
# Out:
#       id_x  budget  popularity  revenue  \
# 58   43692   165.0         724   675.12
# 78   43724   150.0         434   378.86
# 119  43796   140.0         271   655.01
# 120  43797   125.0         206   752.10
# 45   43662   185.0         187  1004.56
# 162  43867   108.0         167   630.16
# 59   43693   160.0         167   825.53
# 5    43606   250.0         155   873.26
# 0    43597   237.0         150  2787.97
# 383  44259    63.0         146   100.85
#
#                                                  title  vote_average  \
# 58                                        Interstellar           8.1
# 78                                  Mad Max: Fury Road           7.2
# 119  Pirates of the Caribbean: The Curse of the Bla...           7.5
# 120              The Hunger Games: Mockingjay - Part 1           6.6
# 45                                     The Dark Knight           8.2
# 162                                        The Martian           7.6
# 59                                           Inception           8.1
# 5                   Batman v Superman: Dawn of Justice           5.7
# 0                                               Avatar           7.2
# 383                                         Fight Club           8.3
#
#      vote_count  year month        day      director_name gender
# 58        10867  2014   Nov  Wednesday  Christopher Nolan   Male
# 78         9427  2015   May  Wednesday      George Miller   Male
# 119        6985  2003   Jul  Wednesday     Gore Verbinski   Male
# 120        5584  2014   Nov    Tuesday   Francis Lawrence   Male
# 45        12002  2008   Jul  Wednesday  Christopher Nolan   Male
# 162        7268  2015   Sep  Wednesday       Ridley Scott   Male
# 59        13752  2010   Jul  Wednesday  Christopher Nolan   Male
# 5          7004  2016   Mar  Wednesday        Zack Snyder   Male
# 0         11800  2009   Dec   Thursday      James Cameron   Male
# 383        9413  1999   Oct     Friday      David Fincher   Male

# %%
#Display the titles of the movies directed by Christopher Nolan

# %%
data.head()
# Out:
#     id_x  budget  popularity  revenue  \
# 0  43597   237.0         150  2787.97
# 1  43598   300.0         139   961.00
# 2  43599   245.0         107   880.67
# 3  43600   250.0         112  1084.94
# 4  43602   258.0         115   890.87
#
#                                       title  vote_average  vote_count  year  \
# 0                                    Avatar           7.2       11800  2009
# 1  Pirates of the Caribbean: At World's End           6.9        4500  2007
# 2                                   Spectre           6.3        4466  2015
# 3                     The Dark Knight Rises           7.6        9106  2012
# 4                              Spider-Man 3           5.9        3576  2007
#
#   month       day      director_name gender
# 0   Dec  Thursday      James Cameron   Male
# 1   May  Saturday     Gore Verbinski   Male
# 2   Oct    Monday         Sam Mendes   Male
# 3   Jul    Monday  Christopher Nolan   Male
# 4   May   Tuesday          Sam Raimi   Male

# %%
data.loc[ data["director_name"] == "Christopher Nolan", ["title"]]
# Out:
#                       title
# 3     The Dark Knight Rises
# 45          The Dark Knight
# 58             Interstellar
# 59                Inception
# 74            Batman Begins
# 565                Insomnia
# 641            The Prestige
# 1341                Memento

# %%
#Display the titles of the movies directed by Christopher Nolan along with their release year
data.loc[ data["director_name"] == "Christopher Nolan", ["title", "year"]]
# Out:
#                       title  year
# 3     The Dark Knight Rises  2012
# 45          The Dark Knight  2008
# 58             Interstellar  2014
# 59                Inception  2010
# 74            Batman Begins  2005
# 565                Insomnia  2002
# 641            The Prestige  2006
# 1341                Memento  2000

# %%
#apply()

# %%
#Task: Give encoding to the Genders: Male --> 0 , Female --> 1

# %%
data.head()
# Out:
#     id_x  budget  popularity  revenue  \
# 0  43597   237.0         150  2787.97
# 1  43598   300.0         139   961.00
# 2  43599   245.0         107   880.67
# 3  43600   250.0         112  1084.94
# 4  43602   258.0         115   890.87
#
#                                       title  vote_average  vote_count  year  \
# 0                                    Avatar           7.2       11800  2009
# 1  Pirates of the Caribbean: At World's End           6.9        4500  2007
# 2                                   Spectre           6.3        4466  2015
# 3                     The Dark Knight Rises           7.6        9106  2012
# 4                              Spider-Man 3           5.9        3576  2007
#
#   month       day      director_name gender
# 0   Dec  Thursday      James Cameron   Male
# 1   May  Saturday     Gore Verbinski   Male
# 2   Oct    Monday         Sam Mendes   Male
# 3   Jul    Monday  Christopher Nolan   Male
# 4   May   Tuesday          Sam Raimi   Male

# %%
def encode_gender(g):
  if g == "Male":
    return 0
  else:
    return 1

# %%
data["gender"] = data["gender"].apply(encode_gender)

# %%
data["gender"]
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1460    0
# 1461    0
# 1462    0
# 1463    0
# 1464    1
# Name: gender, Length: 1465, dtype: int64

# %%
data.head()
# Out:
#     id_x  budget  popularity  revenue  \
# 0  43597   237.0         150  2787.97
# 1  43598   300.0         139   961.00
# 2  43599   245.0         107   880.67
# 3  43600   250.0         112  1084.94
# 4  43602   258.0         115   890.87
#
#                                       title  vote_average  vote_count  year  \
# 0                                    Avatar           7.2       11800  2009
# 1  Pirates of the Caribbean: At World's End           6.9        4500  2007
# 2                                   Spectre           6.3        4466  2015
# 3                     The Dark Knight Rises           7.6        9106  2012
# 4                              Spider-Man 3           5.9        3576  2007
#
#   month       day      director_name  gender
# 0   Dec  Thursday      James Cameron       0
# 1   May  Saturday     Gore Verbinski       0
# 2   Oct    Monday         Sam Mendes       0
# 3   Jul    Monday  Christopher Nolan       0
# 4   May   Tuesday          Sam Raimi       0

# %%
data[ ["revenue", "budget"] ].apply(np.sum) #by default --> axis = 0
# Out:
# revenue    209867.04
# budget      70353.62
# dtype: float64

# %%
data[ ["revenue", "budget"] ].apply(np.sum, axis = 1)
# Out:
# 0       3024.97
# 1       1261.00
# 2       1125.67
# 3       1334.94
# 4       1148.87
#          ...
# 1460       0.32
# 1461       3.18
# 1462       0.00
# 1463       0.00
# 1464       2.26
# Length: 1465, dtype: float64

# %%
data.head()
# Out:
#     id_x  budget  popularity  revenue  \
# 0  43597   237.0         150  2787.97
# 1  43598   300.0         139   961.00
# 2  43599   245.0         107   880.67
# 3  43600   250.0         112  1084.94
# 4  43602   258.0         115   890.87
#
#                                       title  vote_average  vote_count  year  \
# 0                                    Avatar           7.2       11800  2009
# 1  Pirates of the Caribbean: At World's End           6.9        4500  2007
# 2                                   Spectre           6.3        4466  2015
# 3                     The Dark Knight Rises           7.6        9106  2012
# 4                              Spider-Man 3           5.9        3576  2007
#
#   month       day      director_name  gender
# 0   Dec  Thursday      James Cameron       0
# 1   May  Saturday     Gore Verbinski       0
# 2   Oct    Monday         Sam Mendes       0
# 3   Jul    Monday  Christopher Nolan       0
# 4   May   Tuesday          Sam Raimi       0

# %%
def calc_profit(df):
  profit = df["revenue"] - df["budget"]
  return profit

# %%
data["profit"] = data[["revenue", "budget"]].apply(calc_profit, axis = 1)

# %%
data[["revenue", "budget"]]
# Out:
#       revenue  budget
# 0     2787.97  237.00
# 1      961.00  300.00
# 2      880.67  245.00
# 3     1084.94  250.00
# 4      890.87  258.00
# ...       ...     ...
# 1460     0.32    0.00
# 1461     3.15    0.03
# 1462     0.00    0.00
# 1463     0.00    0.00
# 1464     2.04    0.22
#
# [1465 rows x 2 columns]

# %%
data.head()
# Out:
#     id_x  budget  popularity  revenue  \
# 0  43597   237.0         150  2787.97
# 1  43598   300.0         139   961.00
# 2  43599   245.0         107   880.67
# 3  43600   250.0         112  1084.94
# 4  43602   258.0         115   890.87
#
#                                       title  vote_average  vote_count  year  \
# 0                                    Avatar           7.2       11800  2009
# 1  Pirates of the Caribbean: At World's End           6.9        4500  2007
# 2                                   Spectre           6.3        4466  2015
# 3                     The Dark Knight Rises           7.6        9106  2012
# 4                              Spider-Man 3           5.9        3576  2007
#
#   month       day      director_name  gender   profit
# 0   Dec  Thursday      James Cameron       0  2550.97
# 1   May  Saturday     Gore Verbinski       0   661.00
# 2   Oct    Monday         Sam Mendes       0   635.67
# 3   Jul    Monday  Christopher Nolan       0   834.94
# 4   May   Tuesday          Sam Raimi       0   632.87

# %%
data["new_profit"] = data["revenue"] - data["budget"]

# %%
data.head()
# Out:
#     id_x  budget  popularity  revenue  \
# 0  43597   237.0         150  2787.97
# 1  43598   300.0         139   961.00
# 2  43599   245.0         107   880.67
# 3  43600   250.0         112  1084.94
# 4  43602   258.0         115   890.87
#
#                                       title  vote_average  vote_count  year  \
# 0                                    Avatar           7.2       11800  2009
# 1  Pirates of the Caribbean: At World's End           6.9        4500  2007
# 2                                   Spectre           6.3        4466  2015
# 3                     The Dark Knight Rises           7.6        9106  2012
# 4                              Spider-Man 3           5.9        3576  2007
#
#   month       day      director_name  gender   profit  new_profit
# 0   Dec  Thursday      James Cameron       0  2550.97     2550.97
# 1   May  Saturday     Gore Verbinski       0   661.00      661.00
# 2   Oct    Monday         Sam Mendes       0   635.67      635.67
# 3   Jul    Monday  Christopher Nolan       0   834.94      834.94
# 4   May   Tuesday          Sam Raimi       0   632.87      632.87

# %%
#Count the number of movies directed by Christopher Nolan?

# %%
data.loc[ data["director_name"] == "Christopher Nolan", ["title"]].count()
# Out:
# title    8
# dtype: int64

# %%
data["director_name"].value_counts()
# Out:
# Steven Spielberg      26
# Martin Scorsese       19
# Clint Eastwood        19
# Woody Allen           18
# Ridley Scott          16
#                       ..
# Tim Hill               5
# Jonathan Liebesman     5
# Roman Polanski         5
# Larry Charles          5
# Nicole Holofcener      5
# Name: director_name, Length: 199, dtype: int64

# %% [markdown]
# What is Grouping?
#
# Simply it could be understood through the terms - Split, Apply, Combine
#
# <img src="https://learning.oreilly.com/api/v2/epubs/urn:orm:book:9781491912126/files/assets/pyds_03in01.png" height = 350/>

# %%
#Groupby aggregation

# %%
data.groupby("director_name")

# %%
data.groupby("director_name").ngroups
# Out:
# 199

# %%
data.groupby("director_name").groups
# Out:
# {'Adam McKay': [176, 323, 366, 505, 839, 916], 'Adam Shankman': [265, 300, 350, 404, 458, 843, 999, 1231], 'Alejandro González Iñárritu': [106, 749, 1015, 1034, 1077, 1405], 'Alex Proyas': [95, 159, 514, 671, 873], 'Alexander Payne': [793, 1006, 1101, 1211, 1281], 'Andrew Adamson': [11, 43, 328, 501, 947], 'Andrew Niccol': [533, 603, 701, 722, 1439], 'Andrzej Bartkowiak': [349, 549, 754, 911, 924], 'Andy Fickman': [517, 681, 909, 926, 973, 1023], 'Andy Tennant': [314, 320, 464, 593, 676, 885], 'Ang Lee': [99, 134, 748, 840, 1089, 1110, 1132, 1184], 'Anne Fletcher': [610, 650, 736, 789, 1206], 'Antoine Fuqua': [310, 338, 424, 467, 576, 808, 818, 1105], 'Atom Egoyan': [946, 1128, 1164, 1194, 1347, 1416], 'Barry Levinson': [313, 319, 471, 594, 878, 898, 1013, 1037, 1082, 1143, 1185, 1345, 1378], 'Barry Sonnenfeld': [13, 48, 90, 205, 591, 778, 783], 'Ben Stiller': [209, 212, 547, 562, 850], 'Bill Condon': [102, 307, 902, 1233, 1381], 'Bobby Farrelly': [352, 356, 481, 498, 624, 630, 654, 806, 928, 972, 1111], 'Brad Anderson': [1163, 1197, 1350, 1419, 1430], 'Brett Ratner': [24, 39, 188, 207, 238, 292, 405, 456, 920], 'Brian De Palma': [228, 255, 318, 439, 747, 905, 919, 1088, 1232, 1261, 1317, 1354], 'Brian Helgeland': [512, 607, 623, 742, 933], 'Brian Levant': [418, 449, 568, 761, 860, 1003], 'Brian Robbins': [416, 441, 669, 962, 988, 1115], 'Bryan Singer': [6, 32, 33, 44, 122, 216, 297, 1326], 'Cameron Crowe': [335, 434, 488, 503, 513, 698], 'Catherine Hardwicke': [602, 695, 724, 937, 1406, 1412], 'Chris Columbus': [117, 167, 204, 218, 229, 509, 656, 897, 996, 1086, 1129], 'Chris Weitz': [17, 500, 794, 869, 1202, 1267], 'Christopher Nolan': [3, 45, 58, 59, 74, 565, 641, 1341], 'Chuck Russell': [177, 410, 657, 1069, 1097, 1339], 'Clint Eastwood': [369, 426, 447, 482, 490, 520, 530, 535, 645, 727, 731, 786, 787, 899, 974, 986, 1167, 1190, 1313], 'Curtis Hanson': [494, 579, 606, 711, 733, 1057, 1310], 'Danny Boyle': [527, 668, 1083, 1085, 1126, 1168, 1287, 1385], 'Darren Aronofsky': [113, 751, 1187, 1328, 1363, 1458], 'Darren Lynn Bousman': [1241, 1243, 1283, 1338, 1440], 'David Ayer': [50, 273, 741, 1024, 1146, 1407], 'David Cronenberg': [541, 767, 994, 1055, 1254, 1268, 1334], 'David Fincher': [62, 213, 253, 383, 398, 478, 522, 555, 618, 785], 'David Gordon Green': [543, 862, 884, 927, 1376, 1418, 1432, 1459], 'David Koepp': [443, 644, 735, 1041, 1209], 'David Lynch': [583, 1161, 1264, 1340, 1456], 'David O. Russell': [422, 556, 609, 896, 982, 989, 1229, 1304], 'David R. Ellis': [582, 634, 756, 888, 934], 'David Zucker': [569, 619, 965, 1052, 1175], 'Dennis Dugan': [217, 260, 267, 293, 303, 718, 780, 977, 1247], 'Donald Petrie': [427, 507, 570, 649, 858, 894, 1106, 1331], 'Doug Liman': [52, 148, 251, 399, 544, 1318, 1451], 'Edward Zwick': [92, 182, 346, 566, 791, 819, 825], 'F. Gary Gray': [308, 402, 491, 523, 697, 833, 1272, 1380], 'Francis Ford Coppola': [487, 559, 622, 646, 772, 1076, 1155, 1253, 1312], 'Francis Lawrence': [63, 72, 109, 120, 679], 'Frank Coraci': [157, 249, 275, 451, 577, 599, 963], 'Frank Oz': [193, 355, 473, 580, 712, 813, 987], 'Garry Marshall': [329, 496, 528, 571, 784, 893, 1029, 1169], 'Gary Fleder': [518, 667, 689, 867, 981, 1165], 'Gary Winick': [258, 797, 798, 804, 1454], 'Gavin O'Connor': [820, 841, 939, 953, 1444], 'George A. Romero': [250, 1066, 1096, 1278, 1367, 1396], 'George Clooney': [343, 450, 831, 966, 1302], 'George Miller': [78, 103, 233, 287, 1250, 1403, 1450], 'Gore Verbinski': [1, 8, 9, 107, 119, 633, 1040], 'Guillermo del Toro': [35, 252, 419, 486, 1118], 'Gus Van Sant': [595, 1018, 1027, 1159, 1240, 1311, 1398], 'Guy Ritchie': [124, 215, 312, 1093, 1225, 1269, 1420], 'Harold Ramis': [425, 431, 558, 586, 788, 1137, 1166, 1325], 'Ivan Reitman': [274, 643, 816, 883, 910, 935, 1134, 1242], 'James Cameron': [0, 19, 170, 173, 344, 1100, 1320], 'James Ivory': [1125, 1152, 1180, 1291, 1293, 1390, 1397], 'James Mangold': [140, 141, 557, 560, 829, 845, 958, 1145], 'James Wan': [30, 617, 1002, 104 ...

# %%
data.loc[data["director_name"] == "Christopher Nolan"]
# Out:
#        id_x  budget  popularity  revenue                  title  vote_average  \
# 3     43600   250.0         112  1084.94  The Dark Knight Rises           7.6
# 45    43662   185.0         187  1004.56        The Dark Knight           8.2
# 58    43692   165.0         724   675.12           Interstellar           8.1
# 59    43693   160.0         167   825.53              Inception           8.1
# 74    43716   150.0         115   374.22          Batman Begins           7.5
# 565   44630    46.0          41   113.71               Insomnia           6.8
# 641   44793    40.0          74   109.68           The Prestige           8.0
# 1341  47170     9.0          60    39.72                Memento           8.1
#
#       vote_count  year month        day      director_name  gender  profit  \
# 3           9106  2012   Jul     Monday  Christopher Nolan       0  834.94
# 45         12002  2008   Jul  Wednesday  Christopher Nolan       0  819.56
# 58         10867  2014   Nov  Wednesday  Christopher Nolan       0  510.12
# 59         13752  2010   Jul  Wednesday  Christopher Nolan       0  665.53
# 74          7359  2005   Jun     Friday  Christopher Nolan       0  224.22
# 565         1148  2002   May     Friday  Christopher Nolan       0   67.71
# 641         4391  2006   Oct   Thursday  Christopher Nolan       0   69.68
# 1341        4028  2000   Oct  Wednesday  Christopher Nolan       0   30.72
#
#       new_profit
# 3         834.94
# 45        819.56
# 58        510.12
# 59        665.53
# 74        224.22
# 565        67.71
# 641        69.68
# 1341       30.72

# %%
data.groupby("director_name").get_group("Christopher Nolan")
# Out:
#        id_x  budget  popularity  revenue                  title  vote_average  \
# 3     43600   250.0         112  1084.94  The Dark Knight Rises           7.6
# 45    43662   185.0         187  1004.56        The Dark Knight           8.2
# 58    43692   165.0         724   675.12           Interstellar           8.1
# 59    43693   160.0         167   825.53              Inception           8.1
# 74    43716   150.0         115   374.22          Batman Begins           7.5
# 565   44630    46.0          41   113.71               Insomnia           6.8
# 641   44793    40.0          74   109.68           The Prestige           8.0
# 1341  47170     9.0          60    39.72                Memento           8.1
#
#       vote_count  year month        day      director_name  gender  profit  \
# 3           9106  2012   Jul     Monday  Christopher Nolan       0  834.94
# 45         12002  2008   Jul  Wednesday  Christopher Nolan       0  819.56
# 58         10867  2014   Nov  Wednesday  Christopher Nolan       0  510.12
# 59         13752  2010   Jul  Wednesday  Christopher Nolan       0  665.53
# 74          7359  2005   Jun     Friday  Christopher Nolan       0  224.22
# 565         1148  2002   May     Friday  Christopher Nolan       0   67.71
# 641         4391  2006   Oct   Thursday  Christopher Nolan       0   69.68
# 1341        4028  2000   Oct  Wednesday  Christopher Nolan       0   30.72
#
#       new_profit
# 3         834.94
# 45        819.56
# 58        510.12
# 59        665.53
# 74        224.22
# 565        67.71
# 641        69.68
# 1341       30.72

# %%
data["director_name"].value_counts()
# Out:
# Steven Spielberg      26
# Martin Scorsese       19
# Clint Eastwood        19
# Woody Allen           18
# Ridley Scott          16
#                       ..
# Tim Hill               5
# Jonathan Liebesman     5
# Roman Polanski         5
# Larry Charles          5
# Nicole Holofcener      5
# Name: director_name, Length: 199, dtype: int64

# %%
#How to get same output using groupby?

# %%
data.groupby("director_name")["title"].count()
# Out:
# director_name
# Adam McKay                      6
# Adam Shankman                   8
# Alejandro González Iñárritu     6
# Alex Proyas                     5
# Alexander Payne                 5
#                                ..
# Wes Craven                     10
# Wolfgang Petersen               7
# Woody Allen                    18
# Zack Snyder                     7
# Zhang Yimou                     6
# Name: title, Length: 199, dtype: int64

# %%
#For every director, display the year of the first and the latest movie they have directed

# %%
#Director-Name, First year, Last year

# %%
data.groupby("director_name")["year"].aggregate(["min", "max"])
# Out:
#                               min   max
# director_name
# Adam McKay                   2004  2015
# Adam Shankman                2001  2012
# Alejandro González Iñárritu  2000  2015
# Alex Proyas                  1994  2016
# Alexander Payne              1999  2013
# ...                           ...   ...
# Wes Craven                   1984  2011
# Wolfgang Petersen            1981  2006
# Woody Allen                  1977  2013
# Zack Snyder                  2004  2016
# Zhang Yimou                  2002  2014
#
# [199 rows x 2 columns]

# %%
data.groupby("director_name")["budget"].max()
# Out:
# director_name
# Adam McKay                     100.0
# Adam Shankman                   80.0
# Alejandro González Iñárritu    135.0
# Alex Proyas                    140.0
# Alexander Payne                 30.0
#                                ...
# Wes Craven                      40.0
# Wolfgang Petersen              175.0
# Woody Allen                     30.0
# Zack Snyder                    250.0
# Zhang Yimou                     94.0
# Name: budget, Length: 199, dtype: float64

# %%
data_direc_budget = data.groupby("director_name")["budget"].max().reset_index()

# %%
data_direc_budget
# Out:
#                    director_name  budget
# 0                     Adam McKay   100.0
# 1                  Adam Shankman    80.0
# 2    Alejandro González Iñárritu   135.0
# 3                    Alex Proyas   140.0
# 4                Alexander Payne    30.0
# ..                           ...     ...
# 194                   Wes Craven    40.0
# 195            Wolfgang Petersen   175.0
# 196                  Woody Allen    30.0
# 197                  Zack Snyder   250.0
# 198                  Zhang Yimou    94.0
#
# [199 rows x 2 columns]

# %%
#Display the names of only those directors who have directed atleast 1 movie of budget more than 100M

# %%
data_direc_budget.loc[data_direc_budget["budget"]  > 100, ["director_name"]]
# Out:
#                    director_name
# 2    Alejandro González Iñárritu
# 3                    Alex Proyas
# 5                 Andrew Adamson
# 10                       Ang Lee
# 15              Barry Sonnenfeld
# ..                           ...
# 185                    Tim Story
# 187                  Tom Shadyac
# 188                   Tom Tykwer
# 195            Wolfgang Petersen
# 197                  Zack Snyder
#
# [79 rows x 1 columns]

# %%
data_direc_budget.loc[data_direc_budget["budget"]  > 100, "director_name"]
# Out:
# 2      Alejandro González Iñárritu
# 3                      Alex Proyas
# 5                   Andrew Adamson
# 10                         Ang Lee
# 15                Barry Sonnenfeld
#                   ...
# 185                      Tim Story
# 187                    Tom Shadyac
# 188                     Tom Tykwer
# 195              Wolfgang Petersen
# 197                    Zack Snyder
# Name: director_name, Length: 79, dtype: object

# %%
#Display the rows of only those directors who have directed atleast 1 movie of budget more than 100M

# %%
data.head()
# Out:
#     id_x  budget  popularity  revenue  \
# 0  43597   237.0         150  2787.97
# 1  43598   300.0         139   961.00
# 2  43599   245.0         107   880.67
# 3  43600   250.0         112  1084.94
# 4  43602   258.0         115   890.87
#
#                                       title  vote_average  vote_count  year  \
# 0                                    Avatar           7.2       11800  2009
# 1  Pirates of the Caribbean: At World's End           6.9        4500  2007
# 2                                   Spectre           6.3        4466  2015
# 3                     The Dark Knight Rises           7.6        9106  2012
# 4                              Spider-Man 3           5.9        3576  2007
#
#   month       day      director_name  gender   profit  new_profit
# 0   Dec  Thursday      James Cameron       0  2550.97     2550.97
# 1   May  Saturday     Gore Verbinski       0   661.00      661.00
# 2   Oct    Monday         Sam Mendes       0   635.67      635.67
# 3   Jul    Monday  Christopher Nolan       0   834.94      834.94
# 4   May   Tuesday          Sam Raimi       0   632.87      632.87

# %%
names = data_direc_budget.loc[data_direc_budget["budget"]  > 100, "director_name"]

# %%
print(names)
# Out:
# 2      Alejandro González Iñárritu
# 3                      Alex Proyas
# 5                   Andrew Adamson
# 10                         Ang Lee
# 15                Barry Sonnenfeld
#                   ...
# 185                      Tim Story
# 187                    Tom Shadyac
# 188                     Tom Tykwer
# 195              Wolfgang Petersen
# 197                    Zack Snyder
# Name: director_name, Length: 79, dtype: object

# %%
data.loc[ data["director_name"].isin(names) ]
# Out:
#        id_x  budget  popularity  revenue  \
# 0     43597  237.00         150  2787.97
# 1     43598  300.00         139   961.00
# 2     43599  245.00         107   880.67
# 3     43600  250.00         112  1084.94
# 4     43602  258.00         115   890.87
# ...     ...     ...         ...      ...
# 1450  48267    0.40          33   100.00
# 1451  48268    0.20          13     4.51
# 1452  48274    0.00           5     2.61
# 1458  48335    0.06          27     3.22
# 1460  48363    0.00           3     0.32
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# 4                                 Spider-Man 3           5.9        3576
# ...                                        ...           ...         ...
# 1450                                   Mad Max           6.6        1213
# 1451                                  Swingers           6.8         253
# 1452                                     Three           6.3          31
# 1458                                        Pi           7.1         586
# 1460                            The Last Waltz           7.9          64
#
#       year month       day      director_name  gender   profit  new_profit
# 0     2009   Dec  Thursday      James Cameron       0  2550.97     2550.97
# 1     2007   May  Saturday     Gore Verbinski       0   661.00      661.00
# 2     2015   Oct    Monday         Sam Mendes       0   635.67      635.67
# 3     2012   Jul    Monday  Christopher Nolan       0   834.94      834.94
# 4     2007   May   Tuesday          Sam Raimi       0   632.87      632.87
# ...    ...   ...       ...                ...     ...      ...         ...
# 1450  1979   Apr  Thursday      George Miller       0    99.60       99.60
# 1451  1996   Oct    Friday         Doug Liman       0     4.31        4.31
# 1452  2010   Dec  Thursday         Tom Tykwer       0     2.61        2.61
# 1458  1998   Jul    Friday   Darren Aronofsky       0     3.16        3.16
# 1460  1978   May    Monday    Martin Scorsese       0     0.32        0.32
#
# [636 rows x 14 columns]

# %% [markdown]
# #groupby filtering

# %%
data.groupby("director_name").filter(lambda x: x["budget"].max() > 100)
# Out:
#        id_x  budget  popularity  revenue  \
# 0     43597  237.00         150  2787.97
# 1     43598  300.00         139   961.00
# 2     43599  245.00         107   880.67
# 3     43600  250.00         112  1084.94
# 4     43602  258.00         115   890.87
# ...     ...     ...         ...      ...
# 1450  48267    0.40          33   100.00
# 1451  48268    0.20          13     4.51
# 1452  48274    0.00           5     2.61
# 1458  48335    0.06          27     3.22
# 1460  48363    0.00           3     0.32
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# 4                                 Spider-Man 3           5.9        3576
# ...                                        ...           ...         ...
# 1450                                   Mad Max           6.6        1213
# 1451                                  Swingers           6.8         253
# 1452                                     Three           6.3          31
# 1458                                        Pi           7.1         586
# 1460                            The Last Waltz           7.9          64
#
#       year month       day      director_name  gender   profit  new_profit
# 0     2009   Dec  Thursday      James Cameron       0  2550.97     2550.97
# 1     2007   May  Saturday     Gore Verbinski       0   661.00      661.00
# 2     2015   Oct    Monday         Sam Mendes       0   635.67      635.67
# 3     2012   Jul    Monday  Christopher Nolan       0   834.94      834.94
# 4     2007   May   Tuesday          Sam Raimi       0   632.87      632.87
# ...    ...   ...       ...                ...     ...      ...         ...
# 1450  1979   Apr  Thursday      George Miller       0    99.60       99.60
# 1451  1996   Oct    Friday         Doug Liman       0     4.31        4.31
# 1452  2010   Dec  Thursday         Tom Tykwer       0     2.61        2.61
# 1458  1998   Jul    Friday   Darren Aronofsky       0     3.16        3.16
# 1460  1978   May    Monday    Martin Scorsese       0     0.32        0.32
#
# [636 rows x 14 columns]

# %%
#HW- before coming for next lecture: Practing lambda funcitons along with all the above content.

# %% [markdown]
# #doubts

# %%
a = np.arange(6)

# %%
a
# Out:
# array([0, 1, 2, 3, 4, 5])

# %%
b = a.reshape(2,3)

# %%
print(b)
# Out:
# [[0 1 2]
#  [3 4 5]]

# %%
b = np.arange(6).reshape(2,3)
print(b)
# Out:
# [[0 1 2]
#  [3 4 5]]

# %% [markdown]
# #Lec4 here onwards

# %%
#lambda functions

# %%
def cube_n(n):
  return n**3

# %%
ans = cube_n(4)
print(ans)
# Out:
# 64

# %%
a = lambda x: x**3

a(3)
# Out:
# 27

# %%
#task: Categorize a movie as risky or non-risky
#a movie is risky, if its budget is greater than the average revenue of all the movies of that director

# %%
def check_risky(df):
  risky_flag = df["budget"] >= df["revenue"].mean()
  df["risky"] = risky_flag
  return df

# %%
data_risky = data.groupby("director_name").apply(check_risky)
# Out:
# <ipython-input-104-097a060d188f>:1: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   data_risky = data.groupby("director_name").apply(check_risky)

# %%
data_risky.head()
# Out:
#     id_x  budget  popularity  revenue  \
# 0  43597   237.0         150  2787.97
# 1  43598   300.0         139   961.00
# 2  43599   245.0         107   880.67
# 3  43600   250.0         112  1084.94
# 4  43602   258.0         115   890.87
#
#                                       title  vote_average  vote_count  year  \
# 0                                    Avatar           7.2       11800  2009
# 1  Pirates of the Caribbean: At World's End           6.9        4500  2007
# 2                                   Spectre           6.3        4466  2015
# 3                     The Dark Knight Rises           7.6        9106  2012
# 4                              Spider-Man 3           5.9        3576  2007
#
#   month       day      director_name  gender   profit  new_profit  risky
# 0   Dec  Thursday      James Cameron       0  2550.97     2550.97  False
# 1   May  Saturday     Gore Verbinski       0   661.00      661.00  False
# 2   Oct    Monday         Sam Mendes       0   635.67      635.67  False
# 3   Jul    Monday  Christopher Nolan       0   834.94      834.94  False
# 4   May   Tuesday          Sam Raimi       0   632.87      632.87  False

# %%
data_risky.loc[data_risky["risky"] == True]
# Out:
#        id_x  budget  popularity  revenue  \
# 7     43608   200.0         107   586.09
# 12    43614   380.0         135  1045.71
# 15    43618   200.0          37   310.67
# 20    43624   209.0          64   303.03
# 24    43630   210.0           3   459.36
# ...     ...     ...         ...      ...
# 1347  47224     5.0           7     3.26
# 1349  47229     5.0           3     4.84
# 1351  47233     5.0           6     0.00
# 1356  47263    15.0          10     0.00
# 1383  47453     3.5           4     0.00
#
#                                             title  vote_average  vote_count  \
# 7                               Quantum of Solace           6.1        2965
# 12    Pirates of the Caribbean: On Stranger Tides           6.4        4948
# 15                                     Robin Hood           6.2        1398
# 20                                     Battleship           5.5        2114
# 24                          X-Men: The Last Stand           6.3        3525
# ...                                           ...           ...         ...
# 1347                          The Sweet Hereafter           6.8         103
# 1349                         90 Minutes in Heaven           5.4          40
# 1351                                Light Sleeper           5.7          15
# 1356                           Dying of the Light           4.5         118
# 1383                  In the Name of the King III           3.3          19
#
#       year month        day   director_name  gender  profit  new_profit  risky
# 7     2008   Oct   Thursday    Marc Forster       0  386.09      386.09   True
# 12    2011   May   Saturday    Rob Marshall       0  665.71      665.71   True
# 15    2010   May  Wednesday    Ridley Scott       0  110.67      110.67   True
# 20    2012   Apr  Wednesday      Peter Berg       0   94.03       94.03   True
# 24    2006   May  Wednesday    Brett Ratner       0  249.36      249.36   True
# ...    ...   ...        ...             ...     ...     ...         ...    ...
# 1347  1997   May  Wednesday     Atom Egoyan       0   -1.74       -1.74   True
# 1349  2015   Sep     Friday  Michael Polish       0   -0.16       -0.16   True
# 1351  1992   Aug     Friday   Paul Schrader       1   -5.00       -5.00   True
# 1356  2014   Dec   Thursday   Paul Schrader       1  -15.00      -15.00   True
# 1383  2013   Dec     Friday        Uwe Boll       0   -3.50       -3.50   True
#
# [131 rows x 15 columns]

# %%
#Implement value_counts() using groupby

# %%
data["director_name"].value_counts()
# Out:
# Steven Spielberg      26
# Martin Scorsese       19
# Clint Eastwood        19
# Woody Allen           18
# Ridley Scott          16
#                       ..
# Tim Hill               5
# Jonathan Liebesman     5
# Roman Polanski         5
# Larry Charles          5
# Nicole Holofcener      5
# Name: director_name, Length: 199, dtype: int64

# %%
data.groupby("director_name")["title"].count()
# Out:
# director_name
# Adam McKay                      6
# Adam Shankman                   8
# Alejandro González Iñárritu     6
# Alex Proyas                     5
# Alexander Payne                 5
#                                ..
# Wes Craven                     10
# Wolfgang Petersen               7
# Woody Allen                    18
# Zack Snyder                     7
# Zhang Yimou                     6
# Name: title, Length: 199, dtype: int64

# %%
data.groupby("director_name")["title"].count().sort_values()
# Out:
# director_name
# Kevin Reynolds       5
# George Clooney       5
# Gavin O'Connor       5
# Gary Winick          5
# Michael Apted        5
#                     ..
# Spike Lee           16
# Woody Allen         18
# Clint Eastwood      19
# Martin Scorsese     19
# Steven Spielberg    26
# Name: title, Length: 199, dtype: int64

# %%
data.groupby("director_name")["title"].count().sort_values(ascending = False)
# Out:
# director_name
# Steven Spielberg    26
# Clint Eastwood      19
# Martin Scorsese     19
# Woody Allen         18
# Robert Rodriguez    16
#                     ..
# Paul Weitz           5
# John Madden          5
# Paul Verhoeven       5
# John Whitesell       5
# Kevin Reynolds       5
# Name: title, Length: 199, dtype: int64

# %%
#Who is the most productive director? More no.of movies?--> no.of movies/per year

# %%
data.groupby("director_name")["year"].aggregate(["min", "max"])
# Out:
#                               min   max
# director_name
# Adam McKay                   2004  2015
# Adam Shankman                2001  2012
# Alejandro González Iñárritu  2000  2015
# Alex Proyas                  1994  2016
# Alexander Payne              1999  2013
# ...                           ...   ...
# Wes Craven                   1984  2011
# Wolfgang Petersen            1981  2006
# Woody Allen                  1977  2013
# Zack Snyder                  2004  2016
# Zhang Yimou                  2002  2014
#
# [199 rows x 2 columns]

# %%
data_agg = data.groupby("director_name")[["title", "year"]].aggregate(
    {
        "year" : ["min", "max"],
        "title" : "count"
    }
)

# %%
data_agg.head()
# Out:
#                              year       title
#                               min   max count
# director_name
# Adam McKay                   2004  2015     6
# Adam Shankman                2001  2012     8
# Alejandro González Iñárritu  2000  2015     6
# Alex Proyas                  1994  2016     5
# Alexander Payne              1999  2013     5

# %%
data_agg.columns
# Out:
# MultiIndex([( 'year',   'min'),
#             ( 'year',   'max'),
#             ('title', 'count')],
#            )

# %%
data_agg["year"]
# Out:
#                               min   max
# director_name
# Adam McKay                   2004  2015
# Adam Shankman                2001  2012
# Alejandro González Iñárritu  2000  2015
# Alex Proyas                  1994  2016
# Alexander Payne              1999  2013
# ...                           ...   ...
# Wes Craven                   1984  2011
# Wolfgang Petersen            1981  2006
# Woody Allen                  1977  2013
# Zack Snyder                  2004  2016
# Zhang Yimou                  2002  2014
#
# [199 rows x 2 columns]

# %%
a = ["you", "guys" , "are", "awesome"]

# %%
ans = " ".join(a)
print(ans)
# Out:
# you guys are awesome

# %%
new_cols = [ "_".join(col) for col in data_agg.columns]
print(new_cols)
# Out:
# ['year_min', 'year_max', 'title_count']

# %%
data_agg.columns = new_cols

# %%
data_agg.columns
# Out:
# Index(['year_min', 'year_max', 'title_count'], dtype='object')

# %%
data_agg.head()
# Out:
#                              year_min  year_max  title_count
# director_name
# Adam McKay                       2004      2015            6
# Adam Shankman                    2001      2012            8
# Alejandro González Iñárritu      2000      2015            6
# Alex Proyas                      1994      2016            5
# Alexander Payne                  1999      2013            5

# %%
data_agg.reset_index()
# Out:
#                    director_name  year_min  year_max  title_count
# 0                     Adam McKay      2004      2015            6
# 1                  Adam Shankman      2001      2012            8
# 2    Alejandro González Iñárritu      2000      2015            6
# 3                    Alex Proyas      1994      2016            5
# 4                Alexander Payne      1999      2013            5
# ..                           ...       ...       ...          ...
# 194                   Wes Craven      1984      2011           10
# 195            Wolfgang Petersen      1981      2006            7
# 196                  Woody Allen      1977      2013           18
# 197                  Zack Snyder      2004      2016            7
# 198                  Zhang Yimou      2002      2014            6
#
# [199 rows x 4 columns]

# %%
#Way2

# %%
data_agg = data.groupby("director_name")[["year", "title"]].aggregate(
    first_year = ("year", "min"),
    last_year = ("year", "max"),
    movie_count = ("title", "count")
)

# %%
data_agg.head()
# Out:
#                              first_year  last_year  movie_count
# director_name
# Adam McKay                         2004       2015            6
# Adam Shankman                      2001       2012            8
# Alejandro González Iñárritu        2000       2015            6
# Alex Proyas                        1994       2016            5
# Alexander Payne                    1999       2013            5

# %%
data_agg.reset_index()
# Out:
#                    director_name  first_year  last_year  movie_count
# 0                     Adam McKay        2004       2015            6
# 1                  Adam Shankman        2001       2012            8
# 2    Alejandro González Iñárritu        2000       2015            6
# 3                    Alex Proyas        1994       2016            5
# 4                Alexander Payne        1999       2013            5
# ..                           ...         ...        ...          ...
# 194                   Wes Craven        1984       2011           10
# 195            Wolfgang Petersen        1981       2006            7
# 196                  Woody Allen        1977       2013           18
# 197                  Zack Snyder        2004       2016            7
# 198                  Zhang Yimou        2002       2014            6
#
# [199 rows x 4 columns]

# %%
data_agg["years_active"] = data_agg["last_year"] - data_agg["first_year"] + 1
data_agg.head()

#5 and 10 (both inclusive): 5, 6, 7, 8, 9, 10 --> [a,b] : b-a + 1
# Out:
#                              first_year  last_year  movie_count  years_active
# director_name
# Adam McKay                         2004       2015            6            12
# Adam Shankman                      2001       2012            8            12
# Alejandro González Iñárritu        2000       2015            6            16
# Alex Proyas                        1994       2016            5            23
# Alexander Payne                    1999       2013            5            15

# %%
data_agg["movie_per_year"] = data_agg["movie_count"]/data_agg["years_active"]
data_agg.head()
# Out:
#                              first_year  last_year  movie_count  years_active  \
# director_name
# Adam McKay                         2004       2015            6            12
# Adam Shankman                      2001       2012            8            12
# Alejandro González Iñárritu        2000       2015            6            16
# Alex Proyas                        1994       2016            5            23
# Alexander Payne                    1999       2013            5            15
#
#                              movie_per_year
# director_name
# Adam McKay                         0.500000
# Adam Shankman                      0.666667
# Alejandro González Iñárritu        0.375000
# Alex Proyas                        0.217391
# Alexander Payne                    0.333333

# %%
#Display the data of the top 5 most productive directors

# %%
data_agg.sort_values("movie_per_year", ascending = False)
# Out:
#                   first_year  last_year  movie_count  years_active  \
# director_name
# Tyler Perry             2006       2013            9             8
# Jason Friedberg         2006       2010            5             5
# Shawn Levy              2002       2014           11            13
# Robert Rodriguez        1992       2014           16            23
# Adam Shankman           2001       2012            8            12
# ...                      ...        ...          ...           ...
# Lawrence Kasdan         1985       2012            5            28
# Luc Besson              1985       2014            5            30
# Michael Apted           1980       2010            5            31
# Sidney Lumet            1976       2006            5            31
# Robert Redford          1980       2010            5            31
#
#                   movie_per_year
# director_name
# Tyler Perry             1.125000
# Jason Friedberg         1.000000
# Shawn Levy              0.846154
# Robert Rodriguez        0.695652
# Adam Shankman           0.666667
# ...                          ...
# Lawrence Kasdan         0.178571
# Luc Besson              0.166667
# Michael Apted           0.161290
# Sidney Lumet            0.161290
# Robert Redford          0.161290
#
# [199 rows x 5 columns]

# %%
data_agg.to_csv("analysis.csv", sep = ",")

# %%
#Intro to next lecture

# %%
df = pd.read_csv("Pfizer_1.csv")

# %%
df.head()
# Out:
#          Date                Drug_Name    Parameter  1:30:00  2:30:00  \
# 0  15-10-2020  diltiazem hydrochloride  Temperature     23.0     22.0
# 1  15-10-2020  diltiazem hydrochloride     Pressure     12.0     13.0
# 2  15-10-2020      docetaxel injection  Temperature      NaN     17.0
# 3  15-10-2020      docetaxel injection     Pressure      NaN     22.0
# 4  15-10-2020   ketamine hydrochloride  Temperature     24.0      NaN
#
#    3:30:00  4:30:00  5:30:00  6:30:00  7:30:00  8:30:00  9:30:00  10:30:00  \
# 0      NaN     21.0     21.0       22     23.0     21.0     22.0        20
# 1      NaN     11.0     13.0       14     16.0     16.0     24.0        18
# 2     18.0      NaN     17.0       18      NaN      NaN     23.0        23
# 3     22.0      NaN     22.0       23      NaN      NaN     27.0        26
# 4      NaN     27.0      NaN       26     25.0     24.0     23.0        22
#
#    11:30:00  12:30:00
# 0      20.0        21
# 1      19.0        20
# 2      25.0        25
# 3      29.0        28
# 4      21.0        20

# %%
df.shape
# Out:
# (18, 15)

# %%
#melt
#pivot
